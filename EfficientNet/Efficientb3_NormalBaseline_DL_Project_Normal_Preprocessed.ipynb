# %%
#!pip install torchmetrics

# %%
import requests
import os
import logging
import gdown
import random

import torch
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms, models
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchsummary import summary
from torchvision.datasets import VOCSegmentation
import torchmetrics
import torchvision
import albumentations as A

from collections import Counter
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
import cv2
from PIL import Image
from tqdm import tqdm

from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
from scipy.io import loadmat
from sklearn.manifold import TSNE
from torchmetrics.functional.classification import multiclass_accuracy
from torchmetrics.classification import MulticlassF1Score, JaccardIndex, MulticlassPrecision, MulticlassRecall, MulticlassAveragePrecision
import pandas as pd

# %%
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
logging.basicConfig(level=logging.ERROR)

# If there's a GPU available...
if torch.cuda.is_available():    

    # Tell PyTorch to use the GPU.    
    device = torch.device("cuda:0")

    print('There are %d GPU(s) available.' % torch.cuda.device_count())
    print('We will use the GPU:', torch.cuda.get_device_name(0))
    
else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA GeForce RTX 3090

# %%
ROOT_DIR = '/content/drive/MyDrive/Project/Datasets/ocular-disease-recognition-odir5k'
ROOT_DIR = '../Datasets/ocular-disease-recognition-odir5k/'

# %%
IMAGE_FOLDER = ROOT_DIR + '/inception_preprocessed_images'
CSV_PATH = ROOT_DIR + '/dataset_single_eye.csv'
TEST_CSV = ROOT_DIR + '/TESTING_dataset_single_eye.csv'

TRAIN_RATIO, VAL_RATIO, TEST_RATIO = 0.8, 0.1, 0.1

NUM_CLASSES = 8

# %% [markdown]
# ## Baseline: EfficientNet Normal (Preprocessed)

# %% [markdown]
# ### Processing

# %%
class ImageResizer:
    
    def __init__(self, image_width, quality, source_folder, destination_folder, file_name, keep_aspect_ratio):
        self.image_width = image_width
        self.quality = quality
        self.source_folder = source_folder
        self.destination_folder= destination_folder
        self.file_name = file_name
        self.keep_aspect_ration = keep_aspect_ratio

    def run(self):

        # We load the original file, we resize it to a smaller width and correspondent height and
        # also mirror the image when we find a right eye image so they are all left eyes

        file = os.path.join(self.source_folder, self.file_name)
        img = Image.open(file)

        if self.keep_aspect_ration:
            width_percentage = (self.image_width / float(img.size[0]))
            height_size = int((float(img.size[1]) * float(width_percentage)))
            img = img.resize((self.image_width, height_size), Image.ANTIALIAS)
        else:
            img = img.resize((self.image_width, self.image_width), Image.ANTIALIAS)
        if "right" in self.file_name:
            img.transpose(Image.Transpose.FLIP_LEFT_RIGHT).save(os.path.join(self.destination_folder, self.file_name), optimize=True, quality=self.quality)
        else:
            img.save(os.path.join(self.destination_folder, self.file_name), optimize=True, quality=self.quality)

# %%
SRC_PATH = ROOT_DIR + '/preprocessed_images'
DEST_PATH = ROOT_DIR + '/inception_preprocessed_images'

os.makedirs(DEST_PATH, exist_ok = True)

files = [f for f in os.listdir(SRC_PATH) if os.path.isfile(os.path.join(SRC_PATH, f))]
for file in tqdm(files):
    ImageResizer(image_width = 299, quality = 100, source_folder = SRC_PATH, destination_folder = DEST_PATH, file_name = file, keep_aspect_ratio = False).run()

files = [f for f in os.listdir(SRC_PATH) if not(os.path.isfile(os.path.join(DEST_PATH, f)))]
print(len(files))

for file in tqdm(files):
    ImageResizer(image_width = 299, quality = 100, source_folder = SRC_PATH, destination_folder = DEST_PATH, file_name = file, keep_aspect_ratio = False).run()
# Out:
#   0%|          | 0/6392 [00:00<?, ?it/s]C:\Users\krish\AppData\Local\Temp\ipykernel_28356\1977627382.py:24: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   img = img.resize((self.image_width, self.image_width), Image.ANTIALIAS)
# 100%|██████████| 6392/6392 [00:52<00:00, 122.79it/s]
# 0
# 0it [00:00, ?it/s]

# %%
# Mount Drive

# %%
csv = pd.read_csv(CSV_PATH)

csv = csv[csv['NOT DECISIVE'] == 0]

csv['img_exists'] = csv['Image'].apply(lambda x: os.path.isfile(IMAGE_FOLDER + "/" + x))

# drop the rows for which the file does not exist
csv = csv[csv['img_exists']]

csv.drop(columns = ['ID', 'eye', 'Patient Age',	'Patient Sex', 'NOT DECISIVE', 'img_exists'], inplace = True)
csv
# Out:
#                Image  N  D  G  C  A  H  M  O
# 0      970_right.jpg  0  0  0  1  0  0  0  0
# 1       127_left.jpg  0  1  0  0  0  0  0  0
# 2      850_right.jpg  0  1  0  0  0  0  0  0
# 3       37_right.jpg  1  0  0  0  0  0  0  0
# 4     4421_right.jpg  0  1  0  0  0  0  0  0
# ...              ... .. .. .. .. .. .. .. ..
# 5733    199_left.jpg  0  0  0  0  0  0  0  1
# 5734   516_right.jpg  0  1  0  0  0  0  0  0
# 5735   4603_left.jpg  0  1  0  0  0  0  0  0
# 5736  2132_right.jpg  1  0  0  0  0  0  0  0
# 5737  4487_right.jpg  0  1  0  0  0  0  0  0
#
# [5738 rows x 9 columns]

# %%
# images = [img.split('.', 1)[0] for img in os.listdir(IMAGE_FOLDER) if os.path.isfile(os.path.join(IMAGE_FOLDER, img))]
# print(images[:5])

# %%
X = csv['Image'].to_numpy()
Y = csv.drop(['Image'], axis = 1).to_numpy()

print(X.shape)
print(Y.shape)
# Out:
# (5738,)
# (5738, 8)

# %%
class ODIRDataset(Dataset) :
    
    def __init__(self, X, Y, IMG_FOLDER, transform = None) :
        
        '''
        id : list of samples ids as string
        '''

        self.images = X
        self.labels = Y
        self.image_dir = IMG_FOLDER
        self.transform = transform
        
    def __len__(self):
        return len(self.images)
        
    def __getitem__(self, idx):
        
        img_path = os.path.join(self.image_dir, self.images[idx])
        
        image = Image.open(img_path).convert("RGB")

        labels = torch.Tensor(self.labels[idx]).long()

        if(self.transform != None) :
          image = self.transform(image)

        return image, labels

# %%
def train_val_test_split(dataset, train_percent=0.75, val_percent=0.15, test_percent=0.1, seed=None):
    
    # Given a pytorch Dataset, split it

    assert len(X) == len(Y), "X and Y should have the same length"
    assert round(train_percent + val_percent + test_percent,1) == 1.0, "Train, validation, and test percentages should add up to 1.0"

    if seed is not None:
        np.random.seed(seed)
    
    train_size = int(train_percent * len(dataset))
    val_size = int(val_percent * len(dataset))
    test_size = len(dataset) - train_size - val_size

    # use random_split to split the dataset into train, val, and test sets
    train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

    return train_dataset, val_dataset, test_dataset

# %%
BATCH_SIZE = 16
RANDOM_SEED = 69

# %%
transform = transforms.Compose([
    # transforms.Resize(299),
    # transforms.CenterCrop(299),
    transforms.ToTensor(),
    # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# %%
ODIR_Dataset = ODIRDataset(X, Y, IMAGE_FOLDER, transform = transform)

train_dataset, val_dataset, test_dataset = train_val_test_split(ODIR_Dataset, TRAIN_RATIO, VAL_RATIO, TEST_RATIO, RANDOM_SEED)

train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
print(len(train_dataset))
print(len(val_dataset))
print(len(test_dataset))
# Out:
# 4590
# 573
# 575

# %%
print(len(train_dataloader))
print(len(val_dataloader))
print(len(test_dataloader))
# Out:
# 287
# 36
# 36

# %%
train_sample, train_label = train_dataset[9]

print(train_sample.shape)

image_array = np.transpose(train_sample, (1, 2, 0))
plt.imshow(image_array)
plt.show()

# print(train_sample)
print(train_label)
# Out:
# torch.Size([3, 299, 299])
# tensor([1, 0, 0, 0, 0, 0, 0, 0])

# %% [markdown]
# ### **MODEL ARCHITECTURE**

# %%
NUM_CLASSES = 8
LEARNING_RATE = 0.01
DECAY = 1e-6 
MOMENTUM = 0.9
NUM_EPOCHS = 30
PATIENCE = 5

# %%
# model = torch.hub.load('pytorch/vision:v0.10.0', 'inception_v3', pretrained=True)
# model = models.inception_v3(weights=torchvision.models.Inception_V3_Weights.DEFAULT)
model = torchvision.models.efficientnet_b3(parameters = {'weights': torchvision.models.EfficientNet_B3_Weights.DEFAULT}).to(device)
num_ftrs = model.classifier[1].in_features
NUM_CLASSES = 8
model.classifier[1] = torch.nn.Linear(in_features=num_ftrs, out_features=NUM_CLASSES, bias=True)
model.classifier[0] = torch.nn.Dropout(p=0.5, inplace=True)
model = model.to(device)

# %%
summary(model, (3, 480, 480), 16)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [16, 40, 240, 240]           1,080
#        BatchNorm2d-2         [16, 40, 240, 240]              80
#               SiLU-3         [16, 40, 240, 240]               0
#             Conv2d-4         [16, 40, 240, 240]             360
#        BatchNorm2d-5         [16, 40, 240, 240]              80
#               SiLU-6         [16, 40, 240, 240]               0
#  AdaptiveAvgPool2d-7             [16, 40, 1, 1]               0
#             Conv2d-8             [16, 10, 1, 1]             410
#               SiLU-9             [16, 10, 1, 1]               0
#            Conv2d-10             [16, 40, 1, 1]             440
#           Sigmoid-11             [16, 40, 1, 1]               0
# SqueezeExcitation-12         [16, 40, 240, 240]               0
#            Conv2d-13         [16, 24, 240, 240]             960
#       BatchNorm2d-14         [16, 24, 240, 240]              48
#            MBConv-15         [16, 24, 240, 240]               0
#            Conv2d-16         [16, 24, 240, 240]             216
#       BatchNorm2d-17         [16, 24, 240, 240]              48
#              SiLU-18         [16, 24, 240, 240]               0
# AdaptiveAvgPool2d-19             [16, 24, 1, 1]               0
#            Conv2d-20              [16, 6, 1, 1]             150
#              SiLU-21              [16, 6, 1, 1]               0
#            Conv2d-22             [16, 24, 1, 1]             168
#           Sigmoid-23             [16, 24, 1, 1]               0
# SqueezeExcitation-24         [16, 24, 240, 240]               0
#            Conv2d-25         [16, 24, 240, 240]             576
#       BatchNorm2d-26         [16, 24, 240, 240]              48
#   StochasticDepth-27         [16, 24, 240, 240]               0
#            MBConv-28         [16, 24, 240, 240]               0
#            Conv2d-29        [16, 144, 240, 240]           3,456
#       BatchNorm2d-30        [16, 144, 240, 240]             288
#              SiLU-31        [16, 144, 240, 240]               0
#            Conv2d-32        [16, 144, 120, 120]           1,296
#       BatchNorm2d-33        [16, 144, 120, 120]             288
#              SiLU-34        [16, 144, 120, 120]               0
# AdaptiveAvgPool2d-35            [16, 144, 1, 1]               0
#            Conv2d-36              [16, 6, 1, 1]             870
#              SiLU-37              [16, 6, 1, 1]               0
#            Conv2d-38            [16, 144, 1, 1]           1,008
#           Sigmoid-39            [16, 144, 1, 1]               0
# SqueezeExcitation-40        [16, 144, 120, 120]               0
#            Conv2d-41         [16, 32, 120, 120]           4,608
#       BatchNorm2d-42         [16, 32, 120, 120]              64
#            MBConv-43         [16, 32, 120, 120]               0
#            Conv2d-44        [16, 192, 120, 120]           6,144
#       BatchNorm2d-45        [16, 192, 120, 120]             384
#              SiLU-46        [16, 192, 120, 120]               0
#            Conv2d-47        [16, 192, 120, 120]           1,728
#       BatchNorm2d-48        [16, 192, 120, 120]             384
#              SiLU-49        [16, 192, 120, 120]               0
# AdaptiveAvgPool2d-50            [16, 192, 1, 1]               0
#            Conv2d-51              [16, 8, 1, 1]           1,544
#              SiLU-52              [16, 8, 1, 1]               0
#            Conv2d-53            [16, 192, 1, 1]           1,728
#           Sigmoid-54            [16, 192, 1, 1]               0
# SqueezeExcitation-55        [16, 192, 120, 120]               0
#            Conv2d-56         [16, 32, 120, 120]           6,144
#       BatchNorm2d-57         [16, 32, 120, 120]              64
#   StochasticDepth-58         [16, 32, 120, 120]               0
#            MBConv-59         [16, 32, 120, 120]               0
#            Conv2d-60        [16, 192, 120, 120]           6,144
#       BatchNorm2d-61        [16, 192, 120, 120]             384
#              SiLU-62        [16, 192, 120, 120]               0
#            Conv2d-63        [16, 192, 120, 120]           1,728
#       BatchNorm2d-64        [16, 192, 120, 120]             384
#              SiLU-65        [16, 192, 120, 120]               0
# AdaptiveAvgPool2d-66            [16, 192, 1, 1]               0
#            Conv2d-67              [16, 8, 1, 1]           1,544
#              SiLU-68              [16, 8, 1, 1]               0
#            Conv2d-69            [16, 192, 1, 1]           1,728
#           Sigmoid-70            [16, 192, 1, 1]               0
# SqueezeExcitation-71        [16, 192, 120, 120]               0
#            Conv2d-72         [16, 32, 120, 120]           6,144
#       BatchNorm2d-73         [16, 32, 120, 120]              64
#   StochasticDepth-74         [16, 32, 120, 120]               0
#            MBConv-75         [16, 32, 120, 120]               0
#            Conv2d-76        [16, 192, 120, 120]           6,144
#       BatchNorm2d-77        [16, 192, 120, 120]             384
#              SiLU-78        [16, 192, 120, 120]               0
#            Conv2d-79          [16, 192, 60, 60]           4,800
#       BatchNorm2d-80          [16, 192, 60, 60]             384
#              SiLU-81          [16, 192, 60, 60]               0
# AdaptiveAvgPool2d-82            [16, 192, 1, 1]               0
#            Conv2d-83              [16, 8, 1, 1]           1,544
#              SiLU-84              [16, 8, 1, 1]               0
#            Conv2d-85            [16, 192, 1, 1]           1,728
#           Sigmoid-86            [16, 192, 1, 1]               0
# SqueezeExcitation-87          [16, 192, 60, 60]               0
#            Conv2d-88           [16, 48, 60, 60]           9,216
#       BatchNorm2d-89           [16, 48, 60, 60]              96
#            MBConv-90           [16, 48, 60, 60]               0
#            Conv2d-91          [16, 288, 60, 60]          13,824
#       BatchNorm2d-92          [16, 288, 60, 60]             576
#              SiLU-93          [16, 288, 60, 60]               0
#            Conv2d-94          [16, 288, 60, 60]           7,200
#       BatchNorm2d-95          [16, 288, 60, 60]             576
#              SiLU-96          [16, 288, 60, 60]               0
# AdaptiveAvgPool2d-97            [16, 288, 1, 1]               0
#            Conv2d-98             [16, 12, 1, 1]           3,468
#              SiLU-99             [16, 12, 1, 1]               0
#           Conv2d-100            [16, 288, 1, 1]           3,744
#          Sigmoid-101            [16, 288, 1, 1]               0
# SqueezeExcitation-102          [16, 288, 60, 60]               0
#           Conv2d-103           [16, 48, 60, 60]          13,824
#      BatchNorm2d-104           [16, 48, 60, 60]              96
#  StochasticDepth-105           [16, 48, 60, 60]               0
#           MBConv-106           [16, 48, 60, 60]               0
#           Conv2d-107          [16, 288, 60, 60]          13,824
#      BatchNorm2d-108          [16, 288, 60, 60]             576
#             SiLU-109          [16, 288, 60, 60]               0
#           Conv2d-110          [16, 288, 60, 60]           7,200
#      BatchNorm2d-111          [16, 288, 60, 60]             576
#             SiLU-112          [16, 288, 60, 60]               0
# AdaptiveAvgPool2d-113            [16, 288, 1, 1]               0
#           Conv2d-114             [16, 12, 1, 1]           3,468
#             SiLU-115             [16, 12, 1, 1]               0
#           Conv2d-116            [16, 288, 1, 1]           3,744
#          Sigmoid-117            [16, 288, 1, 1]               0
# SqueezeExcitation-118          [16, 288, 60, 60]               0
#           Conv2d-119           [16, 48, 60, 60]          13,824
#      BatchNorm2d-120           [16, 48, 60, 60]              96
#  StochasticDepth-121           [16, 48, 60, 60]               0
#           MBConv-122           [16, 48, 60, 60]               0
#           Conv2d-123          [16, 288, 60, 60]          13,824
#      BatchNorm2d-124          [16, 288, 60, 60]             576
#             SiLU-125          [16, 288, 60, 60]               0
#           Conv2d-126          [16, 288, 30, 30]           2,592
#      BatchNorm2d-127          [16, 288, 30, 30]             576
#             SiLU-128          [16, 288, 30, 30]               0
# AdaptiveAvgPool2d-129            [16, 288, 1, 1]               0
#           Conv2d-130             [16, 12, 1, 1]           3,468
#             SiLU-131             [16, 12, 1, 1]               0
#           Conv2d-132            [16, 288, 1, 1]           3,744
#          Sigmoid-133            [16, 288, 1, 1]               0
# SqueezeExcitation-134          [16, 288, 30, 30]               0
#           Conv2d-135           [16, 96, 30, 30]          27,648
#      BatchNorm2d-136           [16, 96, 30, 30]             192
#           MBConv-137           [16, 96, 30, 30]               0
#           Conv2d-138          [16, 576, 30, 30]          55,296
#      BatchNorm2d-139          [16, 576, 30, 30]           1,152
#             SiLU-140          [16, 576, 30, 30]               0
#           Conv2d-141          [16, 576, 30, 30]           5,184
#      BatchNorm2d-142          [16, 576, 30, 30]           1,152
#             SiLU-143          [16, 576, 30, 30]               0
# AdaptiveAvgPool2d-144            [16, 576, 1, 1]               0
#           Conv2d-145             [16, 24, 1, 1]          13,848
#             SiLU-146             [16, 24, 1, 1]               0
#           Conv2d-147            [16, 576, 1, 1]          14,400
#          Sigmoid-148            [16, 576, 1, 1]               0
# SqueezeExcitation-149          [16, 576, 30, 30]               0
#           Conv2d-150           [16, 96, 30, 30]          55,296
#      BatchNorm2d-151           [16, 96, 30, 30]             192
#  StochasticDepth-152           [16, 96, 30, 30]               0
#           MBConv-153           [16, 96, 30, 30]               0
#           Conv2d-154          [16, 576, 30, 30]          55,296
#      BatchNorm2d-155          [16, 576, 30, 30]           1,152
#             SiLU-156          [16, 576, 30, 30]               0
#           Conv2d-157          [16, 576, 30, 30]           5,184
#      BatchNorm2d-158          [16, 576, 30, 30]           1,152
#             SiLU-159          [16, 576, 30, 30]               0
# AdaptiveAvgPool2d-160            [16, 576, 1, 1]               0
#           Conv2d-161             [16, 24, 1, 1]          13,848
#             SiLU-162             [16, 24, 1, 1]               0
#           Conv2d-163            [16, 576, 1, 1]          14,400
#          Sigmoid-164            [16, 576, 1, 1]               0
# SqueezeExcitation-165          [16, 576, 30, 30]               0
#           Conv2d-166           [16, 96, 30, 30]          55,296
#      BatchNorm2d-167           [16, 96, 30, 30]             192
#  StochasticDepth-168           [16, 96, 30, 30]               0
#           MBConv-169           [16, 96, 30, 30]               0
#           Conv2d-170          [16, 576, 30, 30]          55,296
#      BatchNorm2d-171          [16, 576, 30, 30]           1,152
#             SiLU-172          [16, 576, 30, 30]               0
#           Conv2d-173          [16, 576, 30, 30]           5,184
#      BatchNorm2d-174          [16, 576, 30, 30]           1,152
#             SiLU-175          [16, 576, 30, 30]               0
# AdaptiveAvgPool2d-176            [16, 576, 1, 1]               0
#           Conv2d-177             [16, 24, 1, 1]          13,848
#             SiLU-178             [16, 24, 1, 1]               0
#           Conv2d-179            [16, 576, 1, 1]          14,400
#          Sigmoid-180            [16, 576, 1, 1]               0
# SqueezeExcitation-181          [16, 576, 30, 30]               0
#           Conv2d-182           [16, 96, 30, 30]          55,296
#      BatchNorm2d-183           [16, 96, 30, 30]             192
#  StochasticDepth-184           [16, 96, 30, 30]               0
#           MBConv-185           [16, 96, 30, 30]               0
#           Conv2d-186          [16, 576, 30, 30]          55,296
#      BatchNorm2d-187          [16, 576, 30, 30]           1,152
#             SiLU-188          [16, 576, 30, 30]               0
#           Conv2d-189          [16, 576, 30, 30]           5,184
#      BatchNorm2d-190          [16, 576, 30, 30]           1,152
#             SiLU-191          [16, 576, 30, 30]               0
# AdaptiveAvgPool2d-192            [16, 576, 1, 1]               0
#           Conv2d-193             [16, 24, 1, 1]          13,848
#             SiLU-194             [16, 24, 1, 1]               0
#           Conv2d-195            [16, 576, 1, 1]          14,400
#          Sigmoid-196            [16, 576, 1, 1]               0
# SqueezeExcitation-197          [16, 576, 30, 30]               0
#           Conv2d-198           [16, 96, 30, 30]          55,296
#      BatchNorm2d-199           [16, 96, 30, 30]             192
#  StochasticDepth-200           [16, 96, 30, 30]               0
#           MBConv-201           [16, 96, 30, 30]               0
#           Conv2d-202          [16, 576, 30, 30]          55,296
#      BatchNorm2d-203          [16, 576, 30, 30]           1,152
#             SiLU-204          [16, 576, 30, 30]               0
#           Conv2d-205          [16, 576, 30, 30]          14,400
#      BatchNorm2d-206          [16, 576, 30, 30]           1,152
#             SiLU-207          [16, 576, 30, 30]               0
# AdaptiveAvgPool2d-208            [16, 576, 1, 1]               0
#           Conv2d-209             [16, 24, 1, 1]          13,848
#             SiLU-210             [16, 24, 1, 1]               0
#           Conv2d-211            [16, 576, 1, 1]          14,400
#          Sigmoid-212            [16, 576, 1, 1]               0
# SqueezeExcitation-213          [16, 576, 30, 30]               0
#           Conv2d-214          [16, 136, 30, 30]          78,336
#      BatchNorm2d-215          [16, 136, 30, 30]             272
#           MBConv-216          [16, 136, 30, 30]               0
#           Conv2d-217          [16, 816, 30, 30]         110,976
#      BatchNorm2d-218          [16, 816, 30, 30]           1,632
#             SiLU-219          [16, 816, 30, 30]               0
#           Conv2d-220          [16, 816, 30, 30]          20,400
#      BatchNorm2d-221          [16, 816, 30, 30]           1,632
#             SiLU-222          [16, 816, 30, 30]               0
# AdaptiveAvgPool2d-223            [16, 816, 1, 1]               0
#           Conv2d-224             [16, 34, 1, 1]          27,778
#             SiLU-225             [16, 34, 1, 1]               0
#           Conv2d-226            [16, 816, 1, 1]          28,560
#          Sigmoid-227            [16, 816, 1, 1]               0
# SqueezeExcitation-228          [16, 816, 30, 30]               0
#           Conv2d-229          [16, 136, 30, 30]         110,976
#      BatchNorm2d-230          [16, 136, 30, 30]             272
#  StochasticDepth-231          [16, 136, 30, 30]               0
#           MBConv-232          [16, 136, 30, 30]               0
#           Conv2d-233          [16, 816, 30, 30]         110,976
#      BatchNorm2d-234          [16, 816, 30, 30]           1,632
#             SiLU-235          [16, 816, 30, 30]               0
#           Conv2d-236          [16, 816, 30, 30]          20,400
#      BatchNorm2d-237          [16, 816, 30, 30]           1,632
#             SiLU-238          [16, 816, 30, 30]               0
# AdaptiveAvgPool2d-239            [16, 816, 1, 1]               0
#           Conv2d-240             [16, 34, 1, 1]          27,778
#             SiLU-241             [16, 34, 1, 1]               0
#           Conv2d-242            [16, 816, 1, 1]          28,560
#          Sigmoid-243            [16, 816, 1, 1]               0
# SqueezeExcitation-244          [16, 816, 30, 30]               0
#           Conv2d-245          [16, 136, 30, 30]         110,976
#      BatchNorm2d-246          [16, 136, 30, 30]             272
#  StochasticDepth-247          [16, 136, 30, 30]               0
#           MBConv-248          [16, 136, 30, 30]               0
#           Conv2d-249          [16, 816, 30, 30]         110,976
#      BatchNorm2d-250          [16, 816, 30, 30]           1,632
#             SiLU-251          [16, 816, 30, 30]               0
#           Conv2d-252          [16, 816, 30, 30]          20,400
#      BatchNorm2d-253          [16, 816, 30, 30]           1,632
#             SiLU-254          [16, 816, 30, 30]               0
# AdaptiveAvgPool2d-255            [16, 816, 1, 1]               0
#           Conv2d-256             [16, 34, 1, 1]          27,778
#             SiLU-257             [16, 34, 1, 1]               0
#           Conv2d-258            [16, 816, 1, 1]          28,560
#          Sigmoid-259            [16, 816, 1, 1]               0
# SqueezeExcitation-260          [16, 816, 30, 30]               0
#           Conv2d-261          [16, 136, 30, 30]         110,976
#      BatchNorm2d-262          [16, 136, 30, 30]             272
#  StochasticDepth-263          [16, 136, 30, 30]               0
#           MBConv-264          [16, 136, 30, 30]               0
#           Conv2d-265          [16, 816, 30, 30]         110,976
#      BatchNorm2d-266          [16, 816, 30, 30]           1,632
#             SiLU-267          [16, 816, 30, 30]               0
#           Conv2d-268          [16, 816, 30, 30]          20,400
#      BatchNorm2d-269          [16, 816, 30, 30]           1,632
#             SiLU-270          [16, 816, 30, 30]               0
# AdaptiveAvgPool2d-271            [16, 816, 1, 1]               0
#           Conv2d-272             [16, 34, 1, 1]          27,778
#             SiLU-273             [16, 34, 1, 1]               0
#           Conv2d-274            [16, 816, 1, 1]          28,560
#          Sigmoid-275            [16, 816, 1, 1]               0
# SqueezeExcitation-276          [16, 816, 30, 30]               0
#           Conv2d-277          [16, 136, 30, 30]         110,976
#      BatchNorm2d-278          [16, 136, 30, 30]             272
#  StochasticDepth-279          [16, 136, 30, 30]               0
#           MBConv-280          [16, 136, 30, 30]               0
#           Conv2d-281          [16, 816, 30, 30]         110,976
#      BatchNorm2d-282          [16, 816, 30, 30]           1,632
#             SiLU-283          [16, 816, 30, 30]               0
#           Conv2d-284          [16, 816, 15, 15]          20,400
#      BatchNorm2d-285          [16, 816, 15, 15]           1,632
#             SiLU-286          [16, 816, 15, 15]               0
# AdaptiveAvgPool2d-287            [16, 816, 1, 1]               0
#           Conv2d-288             [16, 34, 1, 1]          27,778
#             SiLU-289             [16, 34, 1, 1]               0
#           Conv2d-290            [16, 816, 1, 1]          28,560
#          Sigmoid-291            [16, 816, 1, 1]               0
# SqueezeExcitation-292          [16, 816, 15, 15]               0
#           Conv2d-293          [16, 232, 15, 15]         189,312
#      BatchNorm2d-294          [16, 232, 15, 15]             464
#           MBConv-295          [16, 232, 15, 15]               0
#           Conv2d-296         [16, 1392, 15, 15]         322,944
#      BatchNorm2d-297         [16, 1392, 15, 15]           2,784
#             SiLU-298         [16, 1392, 15, 15]               0
#           Conv2d-299         [16, 1392, 15, 15]          34,800
#      BatchNorm2d-300         [16, 1392, 15, 15]           2,784
#             SiLU-301         [16, 1392, 15, 15]               0
# AdaptiveAvgPool2d-302           [16, 1392, 1, 1]               0
#           Conv2d-303             [16, 58, 1, 1]          80,794
#             SiLU-304             [16, 58, 1, 1]               0
#           Conv2d-305           [16, 1392, 1, 1]          82,128
#          Sigmoid-306           [16, 1392, 1, 1]               0
# SqueezeExcitation-307         [16, 1392, 15, 15]               0
#           Conv2d-308          [16, 232, 15, 15]         322,944
#      BatchNorm2d-309          [16, 232, 15, 15]             464
#  StochasticDepth-310          [16, 232, 15, 15]               0
#           MBConv-311          [16, 232, 15, 15]               0
#           Conv2d-312         [16, 1392, 15, 15]         322,944
#      BatchNorm2d-313         [16, 1392, 15, 15]           2,784
#             SiLU-314         [16, 1392, 15, 15]               0
#           Conv2d-315         [16, 1392, 15, 15]          34,800
#      BatchNorm2d-316         [16, 1392, 15, 15]           2,784
#             SiLU-317         [16, 1392, 15, 15]               0
# AdaptiveAvgPool2d-318           [16, 1392, 1, 1]               0
#           Conv2d-319             [16, 58, 1, 1]          80,794
#             SiLU-320             [16, 58, 1, 1]               0
#           Conv2d-321           [16, 1392, 1, 1]          82,128
#          Sigmoid-322           [16, 1392, 1, 1]               0
# SqueezeExcitation-323         [16, 1392, 15, 15]               0
#           Conv2d-324          [16, 232, 15, 15]         322,944
#      BatchNorm2d-325          [16, 232, 15, 15]             464
#  StochasticDepth-326          [16, 232, 15, 15]               0
#           MBConv-327          [16, 232, 15, 15]               0
#           Conv2d-328         [16, 1392, 15, 15]         322,944
#      BatchNorm2d-329         [16, 1392, 15, 15]           2,784
#             SiLU-330         [16, 1392, 15, 15]               0
#           Conv2d-331         [16, 1392, 15, 15]          34,800
#      BatchNorm2d-332         [16, 1392, 15, 15]           2,784
#             SiLU-333         [16, 1392, 15, 15]               0
# AdaptiveAvgPool2d-334           [16, 1392, 1, 1]               0
#           Conv2d-335             [16, 58, 1, 1]          80,794
#             SiLU-336             [16, 58, 1, 1]               0
#           Conv2d-337           [16, 1392, 1, 1]          82,128
#          Sigmoid-338           [16, 1392, 1, 1]               0
# SqueezeExcitation-339         [16, 1392, 15, 15]               0
#           Conv2d-340          [16, 232, 15, 15]         322,944
#      BatchNorm2d-341          [16, 232, 15, 15]             464
#  StochasticDepth-342          [16, 232, 15, 15]               0
#           MBConv-343          [16, 232, 15, 15]               0
#           Conv2d-344         [16, 1392, 15, 15]         322,944
#      BatchNorm2d-345         [16, 1392, 15, 15]           2,784
#             SiLU-346         [16, 1392, 15, 15]               0
#           Conv2d-347         [16, 1392, 15, 15]          34,800
#      BatchNorm2d-348         [16, 1392, 15, 15]           2,784
#             SiLU-349         [16, 1392, 15, 15]               0
# AdaptiveAvgPool2d-350           [16, 1392, 1, 1]               0
#           Conv2d-351             [16, 58, 1, 1]          80,794
#             SiLU-352             [16, 58, 1, 1]               0
#           Conv2d-353           [16, 1392, 1, 1]          82,128
#          Sigmoid-354           [16, 1392, 1, 1]               0
# SqueezeExcitation-355         [16, 1392, 15, 15]               0
#           Conv2d-356          [16, 232, 15, 15]         322,944
#      BatchNorm2d-357          [16, 232, 15, 15]             464
#  StochasticDepth-358          [16, 232, 15, 15]               0
#           MBConv-359          [16, 232, 15, 15]               0
#           Conv2d-360         [16, 1392, 15, 15]         322,944
#      BatchNorm2d-361         [16, 1392, 15, 15]           2,784
#             SiLU-362         [16, 1392, 15, 15]               0
#           Conv2d-363         [16, 1392, 15, 15]          34,800
#      BatchNorm2d-364         [16, 1392, 15, 15]           2,784
#             SiLU-365         [16, 1392, 15, 15]               0
# AdaptiveAvgPool2d-366           [16, 1392, 1, 1]               0
#           Conv2d-367             [16, 58, 1, 1]          80,794
#             SiLU-368             [16, 58, 1, 1]               0
#           Conv2d-369           [16, 1392, 1, 1]          82,128
#          Sigmoid-370           [16, 1392, 1, 1]               0
# SqueezeExcitation-371         [16, 1392, 15, 15]               0
#           Conv2d-372          [16, 232, 15, 15]         322,944
#      BatchNorm2d-373          [16, 232, 15, 15]             464
#  StochasticDepth-374          [16, 232, 15, 15]               0
#           MBConv-375          [16, 232, 15, 15]               0
#           Conv2d-376         [16, 1392, 15, 15]         322,944
#      BatchNorm2d-377         [16, 1392, 15, 15]           2,784
#             SiLU-378         [16, 1392, 15, 15]               0
#           Conv2d-379         [16, 1392, 15, 15]          12,528
#      BatchNorm2d-380         [16, 1392, 15, 15]           2,784
#             SiLU-381         [16, 1392, 15, 15]               0
# AdaptiveAvgPool2d-382           [16, 1392, 1, 1]               0
#           Conv2d-383             [16, 58, 1, 1]          80,794
#             SiLU-384             [16, 58, 1, 1]               0
#           Conv2d-385           [16, 1392, 1, 1]          82,128
#          Sigmoid-386           [16, 1392, 1, 1]               0
# SqueezeExcitation-387         [16, 1392, 15, 15]               0
#           Conv2d-388          [16, 384, 15, 15]         534,528
#      BatchNorm2d-389          [16, 384, 15, 15]             768
#           MBConv-390          [16, 384, 15, 15]               0
#           Conv2d-391         [16, 2304, 15, 15]         884,736
#      BatchNorm2d-392         [16, 2304, 15, 15]           4,608
#             SiLU-393         [16, 2304, 15, 15]               0
#           Conv2d-394         [16, 2304, 15, 15]          20,736
#      BatchNorm2d-395         [16, 2304, 15, 15]           4,608
#             SiLU-396         [16, 2304, 15, 15]               0
# AdaptiveAvgPool2d-397           [16, 2304, 1, 1]               0
#           Conv2d-398             [16, 96, 1, 1]         221,280
#             SiLU-399             [16, 96, 1, 1]               0
#           Conv2d-400           [16, 2304, 1, 1]         223,488
#          Sigmoid-401           [16, 2304, 1, 1]               0
# SqueezeExcitation-402         [16, 2304, 15, 15]               0
#           Conv2d-403          [16, 384, 15, 15]         884,736
#      BatchNorm2d-404          [16, 384, 15, 15]             768
#  StochasticDepth-405          [16, 384, 15, 15]               0
#           MBConv-406          [16, 384, 15, 15]               0
#           Conv2d-407         [16, 1536, 15, 15]         589,824
#      BatchNorm2d-408         [16, 1536, 15, 15]           3,072
#             SiLU-409         [16, 1536, 15, 15]               0
# AdaptiveAvgPool2d-410           [16, 1536, 1, 1]               0
#          Dropout-411                 [16, 1536]               0
#           Linear-412                    [16, 8]          12,296
# ================================================================
# Total params: 10,708,528
# Trainable params: 10,708,528
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 42.19
# Forward/backward pass size (MB): 7717.91
# Params size (MB): 40.85
# Estimated Total Size (MB): 7800.95
# ----------------------------------------------------------------
# c:\ProgramData\Anaconda3\envs\ml\lib\site-packages\torchsummary\torchsummary.py:93: RuntimeWarning: overflow encountered in long_scalars
#   total_output += np.prod(summary[layer]["output_shape"])

# %%
def binary_cross_entropy(y_true, y_pred):
    epsilon = 1e-15
    y_pred = torch.clamp(y_pred, min = epsilon, max = 1-epsilon)
    loss = -(y_true * torch.log(y_pred) + (1 - y_true) * torch.log(1 - y_pred))
    mean_loss = torch.mean(loss)
    return mean_loss

def criterion(y_true_batch, y_pred_batch) :
    weight_class = torch.tensor([1,1.2,1.5,1.5,1.5,1.5, 1.5, 1.2]).to(device)
    criterion = torch.nn.BCELoss(weight_class)
    B = y_true_batch.shape[0]
    loss = 0 
    for i in range(B) :
      loss += criterion(y_pred_batch[i],y_true_batch[i])
    return loss/B 

def predictions(scores) :
    
    B = scores.shape[0]
    predictions = torch.empty(B, NUM_CLASSES)
    
    for i in range(B) :
      pred = torch.empty(NUM_CLASSES,)
      for j in range(NUM_CLASSES) : 
        if(scores[i][j] > 0.5) :
          pred[j] = 1
        else :
          pred[j] = 0
      predictions[i] = pred

    return predictions

# %%
class EarlyStopping:

    def __init__(self, patience=5, verbose=False, delta=0, path='checkpoint.pt', trace_func=print):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func

    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)

        elif score < self.best_score + self.delta:
            self.counter += 1
            self.trace_func(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True

        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        if self.verbose:
            self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# %%
optimizer = optim.SGD(model.parameters(), lr=LEARNING_RATE, weight_decay = DECAY, momentum = MOMENTUM, nesterov = True)
early_stopping = EarlyStopping(patience=PATIENCE, verbose=True)

# %%
import time
import datetime

def format_time(elapsed):
    '''
    Takes a time in seconds and returns a string hh:mm:ss
    '''
    # Round to the nearest second.
    elapsed_rounded = int(round((elapsed)))
    
    # Format as hh:mm:ss
    return str(datetime.timedelta(seconds=elapsed_rounded))
    
total_t0 = time.time()

weight_class = torch.tensor([1,1.2,1.5,1.5,1.5,1.5, 1.5, 1.2]).to(device)
criterion = torch.nn.BCELoss(weight_class)

# %%
for epoch in range(NUM_EPOCHS):

    model.train()   # Important when you are using BatchNorm or Dropout Layers as they work differenlty in testing and training.

    train_loss = 0 
    train_acc = 0 
    val_loss = 0
    val_acc = 0

    t0 = time.time()

    for batch_idx, (data, targets) in enumerate((train_dataloader)):

        if batch_idx % 10 == 0 and not batch_idx == 0:
            elapsed = format_time(time.time() - t0)
            print('  Batch {:>5,}  of  {:>5,}.    Elapsed: {:}.'.format(batch_idx, len(train_dataloader), elapsed))

        optimizer.zero_grad() 

        data = data.to(device=device)
        targets = targets.to(device=device)

        scores = model(data)
        scores = torch.sigmoid(scores)

        loss = criterion(scores, targets.float())
        train_loss += loss.item()
        
        preds = predictions(scores).to(device)
        acc = (torch.sum(preds == targets)/(BATCH_SIZE*8))
        train_acc += acc

        loss.backward()
        optimizer.step()

    avg_train_loss = train_loss / len(train_dataloader)
    train_accuracy = train_acc / len(train_dataloader)

    model.eval()

    with torch.no_grad():

      for batch_idx, (data, targets) in enumerate((val_dataloader)) :

        if batch_idx % 10 == 0 and not batch_idx == 0:
            elapsed = format_time(time.time() - t0)
            print('  Batch {:>5,}  of  {:>5,}.    Elapsed: {:}.'.format(batch_idx, len(val_dataloader), elapsed))

        data = data.to(device=device)
        targets = targets.to(device=device)

        scores = model(data)
        scores = torch.sigmoid(scores)

        loss = criterion(scores, targets.float())
        val_loss += loss.item()

        preds = predictions(scores).to(device)
        val_acc += (torch.sum(preds == targets)/(BATCH_SIZE*8))

    avg_val_loss = val_loss / len(val_dataloader)
    val_accuracy = val_acc / len(val_dataloader)

    # wandb.log({'epoch': epoch, 'train_loss': avg_train_loss, 'train_acc': train_accuracy, 'val_loss': avg_val_loss, 'val_acc': val_accuracy})

    print(f"Epoch [{epoch+1}/{NUM_EPOCHS}], "f"Train Loss: {avg_train_loss:.4f}, "f"Train Accuracy: {train_accuracy:.4f}")
    print(f"Epoch [{epoch+1}/{NUM_EPOCHS}], "f"Val Loss: {avg_val_loss:.4f}, "f"Val Accuracy: {val_accuracy:.4f}")

    early_stopping(avg_val_loss, model)

    if early_stopping.early_stop:
        print("Early stopping")
        print('-'*60)
        break  

    print('-'*60)
    torch.cuda.empty_cache()
# Out:
#   Batch    10  of    287.    Elapsed: 0:00:03.
#   Batch    20  of    287.    Elapsed: 0:00:05.
#   Batch    30  of    287.    Elapsed: 0:00:08.
#   Batch    40  of    287.    Elapsed: 0:00:11.
#   Batch    50  of    287.    Elapsed: 0:00:13.
#   Batch    60  of    287.    Elapsed: 0:00:16.
#   Batch    70  of    287.    Elapsed: 0:00:19.
#   Batch    80  of    287.    Elapsed: 0:00:21.
#   Batch    90  of    287.    Elapsed: 0:00:24.
#   Batch   100  of    287.    Elapsed: 0:00:26.
#   Batch   110  of    287.    Elapsed: 0:00:29.
#   Batch   120  of    287.    Elapsed: 0:00:32.
#   Batch   130  of    287.    Elapsed: 0:00:34.
#   Batch   140  of    287.    Elapsed: 0:00:37.
#   Batch   150  of    287.    Elapsed: 0:00:40.
#   Batch   160  of    287.    Elapsed: 0:00:43.
#   Batch   170  of    287.    Elapsed: 0:00:45.
#   Batch   180  of    287.    Elapsed: 0:00:48.
#   Batch   190  of    287.    Elapsed: 0:00:51.
#   Batch   200  of    287.    Elapsed: 0:00:53.
#   Batch   210  of    287.    Elapsed: 0:00:56.
#   Batch   220  of    287.    Elapsed: 0:00:58.
#   Batch   230  of    287.    Elapsed: 0:01:01.
#   Batch   240  of    287.    Elapsed: 0:01:04.
#   Batch   250  of    287.    Elapsed: 0:01:06.
#   Batch   260  of    287.    Elapsed: 0:01:09.
#   Batch   270  of    287.    Elapsed: 0:01:11.
#   Batch   280  of    287.    Elapsed: 0:01:14.
#   Batch    10  of     36.    Elapsed: 0:01:17.
#   Batch    20  of     36.    Elapsed: 0:01:18.
#   Batch    30  of     36.    Elapsed: 0:01:19.
# Epoch [1/30], Train Loss: 0.4048, Train Accuracy: 0.8678
# Epoch [1/30], Val Loss: 2.5095, Val Accuracy: 0.8681
# Validation loss decreased (inf --> 2.509508).  Saving model ...
# ------------------------------------------------------------
#   Batch    10  of    287.    Elapsed: 0:00:03.
#   Batch    20  of    287.    Elapsed: 0:00:05.
#   Batch    30  of    287.    Elapsed: 0:00:08.
#   Batch    40  of    287.    Elapsed: 0:00:11.
#   Batch    50  of    287.    Elapsed: 0:00:13.
#   Batch    60  of    287.    Elapsed: 0:00:16.
#   Batch    70  of    287.    Elapsed: 0:00:18.
#   Batch    80  of    287.    Elapsed: 0:00:21.
#   Batch    90  of    287.    Elapsed: 0:00:24.
#   Batch   100  of    287.    Elapsed: 0:00:26.
#   Batch   110  of    287.    Elapsed: 0:00:29.
#   Batch   120  of    287.    Elapsed: 0:00:32.
#   Batch   130  of    287.    Elapsed: 0:00:34.
#   Batch   140  of    287.    Elapsed: 0:00:37.
#   Batch   150  of    287.    Elapsed: 0:00:39.
#   Batch   160  of    287.    Elapsed: 0:00:42.
#   Batch   170  of    287.    Elapsed: 0:00:45.
#   Batch   180  of    287.    Elapsed: 0:00:47.
#   Batch   190  of    287.    Elapsed: 0:00:50.
#   Batch   200  of    287.    Elapsed: 0:00:53.
#   Batch   210  of    287.    Elapsed: 0:00:56.
#   Batch   220  of    287.    Elapsed: 0:00:59.
#   Batch   230  of    287.    Elapsed: 0:01:02.
#   Batch   240  of    287.    Elapsed: 0:01:05.
#   Batch   250  of    287.    Elapsed: 0:01:08.
#   Batch   260  of    287.    Elapsed: 0:01:11.
#   Batch   270  of    287.    Elapsed: 0:01:14.
#   Batch   280  of    287.    Elapsed: 0:01:16.
#   Batch    10  of     36.    Elapsed: 0:01:19.
#   Batch    20  of     36.    Elapsed: 0:01:21.
#   Batch    30  of     36.    Elapsed: 0:01:22.
# Epoch [2/30], Train Loss: 0.3645, Train Accuracy: 0.8728
# Epoch [2/30], Val Loss: 0.6534, Val Accuracy: 0.8694
# Validation loss decreased (2.509508 --> 0.653444).  Saving model ...
# ------------------------------------------------------------
#   Batch    10  of    287.    Elapsed: 0:00:03.
#   Batch    20  of    287.    Elapsed: 0:00:06.
#   Batch    30  of    287.    Elapsed: 0:00:09.
#   Batch    40  of    287.    Elapsed: 0:00:12.
#   Batch    50  of    287.    Elapsed: 0:00:15.
#   Batch    60  of    287.    Elapsed: 0:00:18.
#   Batch    70  of    287.    Elapsed: 0:00:21.
#   Batch    80  of    287.    Elapsed: 0:00:23.
#   Batch    90  of    287.    Elapsed: 0:00:26.
#   Batch   100  of    287.    Elapsed: 0:00:29.
#   Batch   110  of    287.    Elapsed: 0:00:31.
#   Batch   120  of    287.    Elapsed: 0:00:34.
#   Batch   130  of    287.    Elapsed: 0:00:37.
#   Batch   140  of    287.    Elapsed: 0:00:39.
#   Batch   150  of    287.    Elapsed: 0:00:42.
#   Batch   160  of    287.    Elapsed: 0:00:45.
#   Batch   170  of    287.    Elapsed: 0:00:47.
#   Batch   180  of    287.    Elapsed: 0:00:50.
#   Batch   190  of    287.    Elapsed: 0:00:52.
#   Batch   200  of    287.    Elapsed: 0:00:55.
#   Batch   210  of    287.    Elapsed: 0:00:58.
#   Batch   220  of    287.    Elapsed: 0:01:00.
#   Batch   230  of    287.    Elapsed: 0:01:03.
#   Batch   240  of    287.    Elapsed: 0:01:06.
#   Batch   250  of    287.    Elapsed: 0:01:08.
#   Batch   260  of    287.    Elapsed: 0:01:11.
#   Batch   270  of    287.    Elapsed: 0:01:14.
#   Batch   280  of    287.    Elapsed: 0:01:16.
#   Batch    10  of     36.    Elapsed: 0:01:19.
#   Batch    20  of     36.    Elapsed: 0:01:20.
#   Batch    30  of     36.    Elapsed: 0:01:21.
# Epoch [3/30], Train Loss: 0.3586, Train Accuracy: 0.8727
# Epoch [3/30], Val Loss: 1.0044, Val Accuracy: 0.8704
# EarlyStopping counter: 1 out of 5
# ------------------------------------------------------------
#   Batch    10  of    287.    Elapsed: 0:00:03.
#   Batch    20  of    287.    Elapsed: 0:00:06.
#   Batch    30  of    287.    Elapsed: 0:00:08.
#   Batch    40  of    287.    Elapsed: 0:00:11.
#   Batch    50  of    287.    Elapsed: 0:00:13.
#   Batch    60  of    287.    Elapsed: 0:00:16.
#   Batch    70  of    287.    Elapsed: 0:00:19.
#   Batch    80  of    287.    Elapsed: 0:00:21.
#   Batch    90  of    287.    Elapsed: 0:00:24.
#   Batch   100  of    287.    Elapsed: 0:00:27.
#   Batch   110  of    287.    Elapsed: 0:00:29.
#   Batch   120  of    287.    Elapsed: 0:00:32.
#   Batch   130  of    287.    Elapsed: 0:00:35.
#   Batch   140  of    287.    Elapsed: 0:00:37.
#   Batch   150  of    287.    Elapsed: 0:00:40.
#   Batch   160  of    287.    Elapsed: 0:00:42.
#   Batch   170  of    287.    Elapsed: 0:00:45.
#   Batch   180  of    287.    Elapsed: 0:00:48.
#   Batch   190  of    287.    Elapsed: 0:00:50.
#   Batch   200  of    287.    Elapsed: 0:00:53.
#   Batch   210  of    287.    Elapsed: 0:00:56.
#   Batch   220  of    287.    Elapsed: 0:00:59.
#   Batch   230  of    287.    Elapsed: 0:01:01.
#   Batch   240  of    287.    Elapsed: 0:01:04.
#   Batch   250  of    287.    Elapsed: 0:01:07.
#   Batch   260  of    287.    Elapsed: 0:01:10.
#   Batch   270  of    287.    Elapsed: 0:01:12.
#   Batch   280  of    287.    Elapsed: 0:01:15.
#   Batch    10  of     36.    Elapsed: 0:01:18.
#   Batch    20  of     36.    Elapsed: 0:01:19.
#   Batch    30  of     36.    Elapsed: 0:01:20.
# Epoch [4/30], Train Loss: 0.3464, Train Accuracy: 0.8740
# Epoch [4/30], Val Loss: 0.6461, Val Accuracy: 0.8670
# Validation loss decreased (0.653444 --> 0.646133).  Saving model ...
# ------------------------------------------------------------
#   Batch    10  of    287.    Elapsed: 0:00:03.
#   Batch    20  of    287.    Elapsed: 0:00:05.
#   Batch    30  of    287.    Elapsed: 0:00:08.
#   Batch    40  of    287.    Elapsed: 0:00:11.
#   Batch    50  of    287.    Elapsed: 0:00:14.
#   Batch    60  of    287.    Elapsed: 0:00:17.
#   Batch    70  of    287.    Elapsed: 0:00:20.
#   Batch    80  of    287.    Elapsed: 0:00:22.
#   Batch    90  of    287.    Elapsed: 0:00:25.
#   Batch   100  of    287.    Elapsed: 0:00:28.
#   Batch   110  of    287.    Elapsed: 0:00:30.
#   Batch   120  of    287.    Elapsed: 0:00:33.
#   Batch   130  of    287.    Elapsed: 0:00:35.
#   Batch   140  of    287.    Elapsed: 0:00:38.
#   Batch   150  of    287.    Elapsed: 0:00:41.
#   Batch   160  of    287.    Elapsed: 0:00:43.
#   Batch   170  of    287.    Elapsed: 0:00:46.
#   Batch   180  of    287.    Elapsed: 0:00:49.
#   Batch   190  of    287.    Elapsed: 0:00:51.
#   Batch   200  of    287.    Elapsed: 0:00:54.
#   Batch   210  of    287.    Elapsed: 0:00:57.
#   Batch   220  of    287.    Elapsed: 0:01:01.
#   Batch   230  of    287.    Elapsed: 0:01:04.
#   Batch   240  of    287.    Elapsed: 0:01:07.
#   Batch   250  of    287.    Elapsed: 0:01:10.
#   Batch   260  of    287.    Elapsed: 0:01:13.
#   Batch   270  of    287.    Elapsed: 0:01:16.
#   Batch   280  of    287.    Elapsed: 0:01:19.
#   Batch    10  of     36.    Elapsed: 0:01:22.
#   Batch    20  of     36.    Elapsed: 0:01:23.
#   Batch    30  of     36.    Elapsed: 0:01:24.
# Epoch [5/30], Train Loss: 0.3445, Train Accuracy: 0.8734
# Epoch [5/30], Val Loss: 0.6918, Val Accuracy: 0.8700
# EarlyStopping counter: 1 out of 5
# ------------------------------------------------------------
#   Batch    10  of    287.    Elapsed: 0:00:03.
#   Batch    20  of    287.    Elapsed: 0:00:05.
#   Batch    30  of    287.    Elapsed: 0:00:08.
#   Batch    40  of    287.    Elapsed: 0:00:11.
#   Batch    50  of    287.    Elapsed: 0:00:13.
#   Batch    60  of    287.    Elapsed: 0:00:16.
#   Batch    70  of    287.    Elapsed: 0:00:19.
#   Batch    80  of    287.    Elapsed: 0:00:22.
#   Batch    90  of    287.    Elapsed: 0:00:25.
#   Batch   100  of    287.    Elapsed: 0:00:28.
#   Batch   110  of    287.    Elapsed: 0:00:31.
#   Batch   120  of    287.    Elapsed: 0:00:34.
#   Batch   130  of    287.    Elapsed: 0:00:37.
#   Batch   140  of    287.    Elapsed: 0:00:40.
#   Batch   150  of    287.    Elapsed: 0:00:43.
#   Batch   160  of    287.    Elapsed: 0:00:46.
#   Batch   170  of    287.    Elapsed: 0:00:50.
#   Batch   180  of    287.    Elapsed: 0:00:53.
#   Batch   190  of    287.    Elapsed: 0:00:56.
#   Batch   200  of    287.    Elapsed: 0:00:59.
#   Batch   210  of    287.    Elapsed: 0:01:02.
#   Batch   220  of    287.    Elapsed: 0:01:05.
#   Batch   230  of    287.    Elapsed: 0:01:08.
#   Batch   240  of    287.    Elapsed: 0:01:11.
#   Batch   250  of    287.    Elapsed: 0:01:14.
#   Batch   260  of    287.    Elapsed: 0:01:17.
#   Batch   270  of    287.    Elapsed: 0:01:20.
#   Batch   280  of    287.    Elapsed: 0:01:23.
#   Batch    10  of     36.    Elapsed: 0:01:26.
#   Batch    20  of     36.    Elapsed: 0:01:27.
#   Batch    30  of     36.    Elapsed: 0:01:28.
# Epoch [6/30], Train Loss: 0.3379, Train Accuracy: 0.8767
# Epoch [6/30], Val Loss: 0.4106, Val Accuracy: 0.8737
# Validation loss decreased (0.646133 --> 0.410604).  Saving model ...
# ------------------------------------------------------------
#   Batch    10  of    287.    Elapsed: 0:00:03.
#   Batch    20  of    287.    Elapsed: 0:00:06.
#   Batch    30  of    287.    Elapsed: 0:00:09.
#   Batch    40  of    287.    Elapsed: 0:00:12.
#   Batch    50  of    287.    Elapsed: 0:00:15.
#   Batch    60  of    287.    Elapsed: 0:00:18.
#   Batch    70  of    287.    Elapsed: 0:00:21.
#   Batch    80  of    287.    Elapsed: 0:00:24.
#   Batch    90  of    287.    Elapsed: 0:00:27.
#   Batch   100  of    287.    Elapsed: 0:00:30.
#   Batch   110  of    287.    Elapsed: 0:00:33.
#   Batch   120  of    287.    Elapsed: 0:00:36.
#   Batch   130  of    287.    Elapsed: 0:00:39.
#   Batch   140  of    287.    Elapsed: 0:00:42.
#   Batch   150  of    287.    Elapsed: 0:00:44.
#   Batch   160  of    287.    Elapsed: 0:00:47.
#   Batch   170  of    287.    Elapsed: 0:00:49.
#   Batch   180  of    287.    Elapsed: 0:00:52.
#   Batch   190  of    287.    Elapsed: 0:00:55.
#   Batch   200  of    287.    Elapsed: 0:00:57.
#   Batch   210  of    287.    Elapsed: 0:01:00.
#   Batch   220  of    287.    Elapsed: 0:01:03.
#   Batch   230  of    287.    Elapsed: 0:01:05.
#   Batch   240  of    287.    Elapsed: 0:01:08.
#   Batch   250  of    287.    Elapsed: 0:01:10.
#   Batch   260  of    287.    Elapsed: 0:01:13.
#   Batch   270  of    287.    Elapsed: 0:01:16.
#   Batch   280  of    287.    Elapsed: 0:01:18.
#   Batch    10  of     36.    Elapsed: 0:01:21.
#   Batch    20  of     36.    Elapsed: 0:01:22.
#   Batch    30  of     36.    Elapsed: 0:01:23.
# Epoch [7/30], Train Loss: 0.3309, Train Accuracy: 0.8787
# Epoch [7/30], Val Loss: 0.4103, Val Accuracy: 0.8722
# Validation loss decreased (0.410604 --> 0.410334).  Saving model ...
# ------------------------------------------------------------
#   Batch    10  of    287.    Elapsed: 0:00:03.
#   Batch    20  of    287.    Elapsed: 0:00:06.
#   Batch    30  of    287.    Elapsed: 0:00:08.
#   Batch    40  of    287.    Elapsed: 0:00:11.
#   Batch    50  of    287.    Elapsed: 0:00:14.
#   Batch    60  of    287.    Elapsed: 0:00:16.
#   Batch    70  of    287.    Elapsed: 0:00:19.
#   Batch    80  of    287.    Elapsed: 0:00:21.
#   Batch    90  of    287.    Elapsed: 0:00:24.
#   Batch   100  of    287.    Elapsed: 0:00:27.
#   Batch   110  of    287.    Elapsed: 0:00:29.
#   Batch   120  of    287.    Elapsed: 0:00:32.
#   Batch   130  of    287.    Elapsed: 0:00:34.
#   Batch   140  of    287.    Elapsed: 0:00:37.
#   Batch   150  of    287.    Elapsed: 0:00:40.
#   Batch   160  of    287.    Elapsed: 0:00:42.
#   Batch   170  of    287.    Elapsed: 0:00:45.
#   Batch   180  of    287.    Elapsed: 0:00:47.
#   Batch   190  of    287.    Elapsed: 0:00:50.
#   Batch   200  of    287.    Elapsed: 0:00:53.
#   Batch   210  of    287.    Elapsed: 0:00:55.
#   Batch   220  of    287.    Elapsed: 0:00:58.
#   Batch   230  of    287.    Elapsed: 0:01:01.
#   Batch   240  of    287.    Elapsed: 0:01:03.
#   Batch   250  of    287.    Elapsed: 0:01:06.
#   Batch   260  of    287.    Elapsed: 0:01:09.
#   Batch   270  of    287.    Elapsed: 0:01:11.
#   Batch   280  of    287.    Elapsed: 0:01:14.
#   Batch    10  of     36.    Elapsed: 0:01:17.
#   Batch    20  of     36.    Elapsed: 0:01:18.
#   Batch    30  of     36.    Elapsed: 0:01:19.
# Epoch [8/30], Train Loss: 0.3250, Train Accuracy: 0.8801
# Epoch [8/30], Val Loss: 0.3300, Val Accuracy: 0.8789
# Validation loss decreased (0.410334 --> 0.329985).  Saving model ...
# ------------------------------------------------------------
#   Batch    10  of    287.    Elapsed: 0:00:03.
#   Batch    20  of    287.    Elapsed: 0:00:05.
#   Batch    30  of    287.    Elapsed: 0:00:08.
#   Batch    40  of    287.    Elapsed: 0:00:11.
#   Batch    50  of    287.    Elapsed: 0:00:13.
#   Batch    60  of    287.    Elapsed: 0:00:16.
#   Batch    70  of    287.    Elapsed: 0:00:19.
#   Batch    80  of    287.    Elapsed: 0:00:21.
#   Batch    90  of    287.    Elapsed: 0:00:24.
#   Batch   100  of    287.    Elapsed: 0:00:26.
#   Batch   110  of    287.    Elapsed: 0:00:29.
#   Batch   120  of    287.    Elapsed: 0:00:32.
#   Batch   130  of    287.    Elapsed: 0:00:34.
#   Batch   140  of    287.    Elapsed: 0:00:37.
#   Batch   150  of    287.    Elapsed: 0:00:40.
#   Batch   160  of    287.    Elapsed: 0:00:43.
#   Batch   170  of    287.    Elapsed: 0:00:45.
#   Batch   180  of    287.    Elapsed: 0:00:48.
#   Batch   190  of    287.    Elapsed: 0:00:50.
#   Batch   200  of    287.    Elapsed: 0:00:53.
#   Batch   210  of    287.    Elapsed: 0:00:56.
#   Batch   220  of    287.    Elapsed: 0:00:58.
#   Batch   230  of    287.    Elapsed: 0:01:01.
#   Batch   240  of    287.    Elapsed: 0:01:04.
#   Batch   250  of    287.    Elapsed: 0:01:06.
#   Batch   260  of    287.    Elapsed: 0:01:09.
#   Batch   270  of    287.    Elapsed: 0:01:11.
#   Batch   280  of    287.    Elapsed: 0:01:14.
#   Batch    10  of     36.    Elapsed: 0:01:17.
#   Batch    20  of     36.    Elapsed: 0:01:18.
#   Batch    30  of     36.    Elapsed: 0:01:19.
# Epoch [9/30], Train Loss: 0.3199, Train Accuracy: 0.8791
# Epoch [9/30], Val Loss: 0.3265, Val Accuracy: 0.8741
# Validation loss decreased (0.329985 --> 0.326486).  Saving model ...
# ------------------------------------------------------------
#   Batch    10  of    287.    Elapsed: 0:00:03.
#   Batch    20  of    287.    Elapsed: 0:00:05.
#   Batch    30  of    287.    Elapsed: 0:00:08.
#   Batch    40  of    287.    Elapsed: 0:00:11.
#   Batch    50  of    287.    Elapsed: 0:00:13.
#   Batch    60  of    287.    Elapsed: 0:00:16.
#   Batch    70  of    287.    Elapsed: 0:00:19.
#   Batch    80  of    287.    Elapsed: 0:00:21.
#   Batch    90  of    287.    Elapsed: 0:00:24.
#   Batch   100  of    287.    Elapsed: 0:00:27.
#   Batch   110  of    287.    Elapsed: 0:00:29.
#   Batch   120  of    287.    Elapsed: 0:00:32.
#   Batch   130  of    287.    Elapsed: 0:00:34.
#   Batch   140  of    287.    Elapsed: 0:00:37.
#   Batch   150  of    287.    Elapsed: 0:00:40.
#   Batch   160  of    287.    Elapsed: 0:00:43.
#   Batch   170  of    287.    Elapsed: 0:00:46.
#   Batch   180  of    287.    Elapsed: 0:00:49.
#   Batch   190  of    287.    Elapsed: 0:00:51.
#   Batch   200  of    287.    Elapsed: 0:00:54.
#   Batch   210  of    287.    Elapsed: 0:00:57.
#   Batch   220  of    287.    Elapsed: 0:00:59.
#   Batch   230  of    287.    Elapsed: 0:01:02.
#   Batch   240  of    287.    Elapsed: 0:01:05.
#   Batch   250  of    287.    Elapsed: 0:01:07.
#   Batch   260  of    287.    Elapsed: 0:01:10.
#   Batch   270  of    287.    Elapsed: 0:01:13.
#   Batch   280  of    287.    Elapsed: 0:01:15.
#   Batch    10  of     36.    Elapsed: 0:01:18.
#   Batch    20  of     36.    Elapsed: 0:01:19.
#   Batch    30  of     36.    Elapsed: 0:01:20.
# Epoch [10/30], Train Loss: 0.3159, Train Accuracy: 0.8798
# Epoch [10/30], Val Loss: 0.3472, Val Accuracy: 0.8785
# EarlyStopping counter: 1 out of 5
# ------------------------------------------------------------
#   Batch    10  of    287.    Elapsed: 0:00:03.
#   Batch    20  of    287.    Elapsed: 0:00:05.
#   Batch    30  of    287.    Elapsed: 0:00:08.
#   Batch    40  of    287.    Elapsed: 0:00:11.
#   Batch    50  of    287.    Elapsed: 0:00:13.
#   Batch    60  of    287.    Elapsed: 0:00:16.
#   Batch    70  of    287.    Elapsed: 0:00:18.
#   Batch    80  of    287.    Elapsed: 0:00:21.
#   Batch    90  of    287.    Elapsed: 0:00:24.
#   Batch   100  of    287.    Elapsed: 0:00:26.
#   Batch   110  of    287.    Elapsed: 0:00:29.
#   Batch   120  of    287.    Elapsed: 0:00:32.
#   Batch   130  of    287.    Elapsed: 0:00:35.
#   Batch   140  of    287.    Elapsed: 0:00:37.
#   Batch   150  of    287.    Elapsed: 0:00:40.
#   Batch   160  of    287.    Elapsed: 0:00:43.
#   Batch   170  of    287.    Elapsed: 0:00:46.
#   Batch   180  of    287.    Elapsed: 0:00:49.
#   Batch   190  of    287.    Elapsed: 0:00:51.
#   Batch   200  of    287.    Elapsed: 0:00:54.
#   Batch   210  of    287.    Elapsed: 0:00:57.
#   Batch   220  of    287.    Elapsed: 0:01:00.
#   Batch   230  of    287.    Elapsed: 0:01:02.
#   Batch   240  of    287.    Elapsed: 0:01:05.
#   Batch   250  of    287.    Elapsed: 0:01:07.
#   Batch   260  of    287.    Elapsed: 0:01:10.
#   Batch   270  of    287.    Elapsed: 0:01:13.
#   Batch   280  of    287.    Elapsed: 0:01:15.
#   Batch    10  of     36.    Elapsed: 0:01:18.
#   Batch    20  of     36.    Elapsed: 0:01:19.
#   Batch    30  of     36.    Elapsed: 0:01:20.
# Epoch [11/30], Train Loss: 0.3132, Train Accuracy: 0.8821
# Epoch [11/30], Val Loss: 0.3257, Val Accuracy: 0.8785
# Validation loss decreased (0.326486 --> 0.325701).  Saving model ...
# ------------------------------------------------------------
#   Batch    10  of    287.    Elapsed: 0:00:03.
#   Batch    20  of    287.    Elapsed: 0:00:05.
#   Batch    30  of    287.    Elapsed: 0:00:08.
#   Batch    40  of    287.    Elapsed: 0:00:11.
#   Batch    50  of    287.    Elapsed: 0:00:13.
#   Batch    60  of    287.    Elapsed: 0:00:16.
#   Batch    70  of    287.    Elapsed: 0:00:19.
#   Batch    80  of    287.    Elapsed: 0:00:21.
#   Batch    90  of    287.    Elapsed: 0:00:24.
#   Batch   100  of    287.    Elapsed: 0:00:26.
#   Batch   110  of    287.    Elapsed: 0:00:29.
#   Batch   120  of    287.    Elapsed: 0:00:32.
#   Batch   130  of    287.    Elapsed: 0:00:35.
#   Batch   140  of    287.    Elapsed: 0:00:38.
#   Batch   150  of    287.    Elapsed: 0:00:40.
#   Batch   160  of    287.    Elapsed: 0:00:43.
#   Batch   170  of    287.    Elapsed: 0:00:45.
#   Batch   180  of    287.    Elapsed: 0:00:48.
#   Batch   190  of    287.    Elapsed: 0:00:51.
#   Batch   200  of    287.    Elapsed: 0:00:53.
#   Batch   210  of    287.    Elapsed: 0:00:56.
#   Batch   220  of    287.    Elapsed: 0:00:59.
#   Batch   230  of    287.    Elapsed: 0:01:01.
#   Batch   240  of    287.    Elapsed: 0:01:04.
#   Batch   250  of    287.    Elapsed: 0:01:06.
#   Batch   260  of    287.    Elapsed: 0:01:09.
#   Batch   270  of    287.    Elapsed: 0:01:12.
#   Batch   280  of    287.    Elapsed: 0:01:14.
#   Batch    10  of     36.    Elapsed: 0:01:17.
#   Batch    20  of     36.    Elapsed: 0:01:18.
#   Batch    30  of     36.    Elapsed: 0:01:19.
# Epoch [12/30], Train Loss: 0.3061, Train Accuracy: 0.8849
# Epoch [12/30], Val Loss: 0.3167, Val Accuracy: 0.8856
# Validation loss decreased (0.325701 --> 0.316731).  Saving model ...
# ------------------------------------------------------------
#   Batch    10  of    287.    Elapsed: 0:00:03.
#   Batch    20  of    287.    Elapsed: 0:00:06.
#   Batch    30  of    287.    Elapsed: 0:00:08.
#   Batch    40  of    287.    Elapsed: 0:00:11.
#   Batch    50  of    287.    Elapsed: 0:00:14.
#   Batch    60  of    287.    Elapsed: 0:00:16.
#   Batch    70  of    287.    Elapsed: 0:00:19.
#   Batch    80  of    287.    Elapsed: 0:00:21.
#   Batch    90  of    287.    Elapsed: 0:00:24.
#   Batch   100  of    287.    Elapsed: 0:00:27.
#   Batch   110  of    287.    Elapsed: 0:00:29.
#   Batch   120  of    287.    Elapsed: 0:00:32.
#   Batch   130  of    287.    Elapsed: 0:00:35.
#   Batch   140  of    287.    Elapsed: 0:00:37.
#   Batch   150  of    287.    Elapsed: 0:00:40.
#   Batch   160  of    287.    Elapsed: 0:00:42.
#   Batch   170  of    287.    Elapsed: 0:00:45.
#   Batch   180  of    287.    Elapsed: 0:00:48.
#   Batch   190  of    287.    Elapsed: 0:00:50.
#   Batch   200  of    287.    Elapsed: 0:00:53.
#   Batch   210  of    287.    Elapsed: 0:00:56.
#   Batch   220  of    287.    Elapsed: 0:00:58.
#   Batch   230  of    287.    Elapsed: 0:01:01.
#   Batch   240  of    287.    Elapsed: 0:01:03.
#   Batch   250  of    287.    Elapsed: 0:01:06.
#   Batch   260  of    287.    Elapsed: 0:01:09.
#   Batch   270  of    287.    Elapsed: 0:01:12.
#   Batch   280  of    287.    Elapsed: 0:01:14.
#   Batch    10  of     36.    Elapsed: 0:01:17.
#   Batch    20  of     36.    Elapsed: 0:01:18.
#   Batch    30  of     36.    Elapsed: 0:01:19.
# Epoch [13/30], Train Loss: 0.3038, Train Accuracy: 0.8871
# Epoch [13/30], Val Loss: 0.3323, Val Accuracy: 0.8752
# EarlyStopping counter: 1 out of 5
# ------------------------------------------------------------
#   Batch    10  of    287.    Elapsed: 0:00:03.
#   Batch    20  of    287.    Elapsed: 0:00:06.
#   Batch    30  of    287.    Elapsed: 0:00:08.
#   Batch    40  of    287.    Elapsed: 0:00:11.
#   Batch    50  of    287.    Elapsed: 0:00:14.
#   Batch    60  of    287.    Elapsed: 0:00:16.
#   Batch    70  of    287.    Elapsed: 0:00:19.
#   Batch    80  of    287.    Elapsed: 0:00:22.
#   Batch    90  of    287.    Elapsed: 0:00:24.
#   Batch   100  of    287.    Elapsed: 0:00:27.
#   Batch   110  of    287.    Elapsed: 0:00:29.
#   Batch   120  of    287.    Elapsed: 0:00:32.
#   Batch   130  of    287.    Elapsed: 0:00:35.
#   Batch   140  of    287.    Elapsed: 0:00:37.
#   Batch   150  of    287.    Elapsed: 0:00:40.
#   Batch   160  of    287.    Elapsed: 0:00:43.
#   Batch   170  of    287.    Elapsed: 0:00:45.
#   Batch   180  of    287.    Elapsed: 0:00:48.
#   Batch   190  of    287.    Elapsed: 0:00:51.
#   Batch   200  of    287.    Elapsed: 0:00:54.
#   Batch   210  of    287.    Elapsed: 0:00:56.
#   Batch   220  of    287.    Elapsed: 0:00:59.
#   Batch   230  of    287.    Elapsed: 0:01:01.
#   Batch   240  of    287.    Elapsed: 0:01:04.
#   Batch   250  of    287.    Elapsed: 0:01:07.
#   Batch   260  of    287.    Elapsed: 0:01:09.
#   Batch   270  of    287.    Elapsed: 0:01:12.
#   Batch   280  of    287.    Elapsed: 0:01:15.
#   Batch    10  of     36.    Elapsed: 0:01:18.
#   Batch    20  of     36.    Elapsed: 0:01:19.
#   Batch    30  of     36.    Elapsed: 0:01:20.
# Epoch [14/30], Train Loss: 0.2976, Train Accuracy: 0.8875
# Epoch [14/30], Val Loss: 0.3424, Val Accuracy: 0.8789
# EarlyStopping counter: 2 out of 5
# ------------------------------------------------------------
#   Batch    10  of    287.    Elapsed: 0:00:03.
#   Batch    20  of    287.    Elapsed: 0:00:06.
#   Batch    30  of    287.    Elapsed: 0:00:08.
#   Batch    40  of    287.    Elapsed: 0:00:11.
#   Batch    50  of    287.    Elapsed: 0:00:14.
#   Batch    60  of    287.    Elapsed: 0:00:17.
#   Batch    70  of    287.    Elapsed: 0:00:19.
#   Batch    80  of    287.    Elapsed: 0:00:22.
#   Batch    90  of    287.    Elapsed: 0:00:25.
#   Batch   100  of    287.    Elapsed: 0:00:27.
#   Batch   110  of    287.    Elapsed: 0:00:30.
#   Batch   120  of    287.    Elapsed: 0:00:32.
#   Batch   130  of    287.    Elapsed: 0:00:35.
#   Batch   140  of    287.    Elapsed: 0:00:37.
#   Batch   150  of    287.    Elapsed: 0:00:40.
#   Batch   160  of    287.    Elapsed: 0:00:43.
#   Batch   170  of    287.    Elapsed: 0:00:45.
#   Batch   180  of    287.    Elapsed: 0:00:48.
#   Batch   190  of    287.    Elapsed: 0:00:51.
#   Batch   200  of    287.    Elapsed: 0:00:53.
#   Batch   210  of    287.    Elapsed: 0:00:56.
#   Batch   220  of    287.    Elapsed: 0:00:59.
#   Batch   230  of    287.    Elapsed: 0:01:02.
#   Batch   240  of    287.    Elapsed: 0:01:05.
#   Batch   250  of    287.    Elapsed: 0:01:08.
#   Batch   260  of    287.    Elapsed: 0:01:11.
#   Batch   270  of    287.    Elapsed: 0:01:13.
#   Batch   280  of    287.    Elapsed: 0:01:16.
#   Batch    10  of     36.    Elapsed: 0:01:19.
#   Batch    20  of     36.    Elapsed: 0:01:20.
#   Batch    30  of     36.    Elapsed: 0:01:21.
# Epoch [15/30], Train Loss: 0.2954, Train Accuracy: 0.8875
# Epoch [15/30], Val Loss: 0.3047, Val Accuracy: 0.8772
# Validation loss decreased (0.316731 --> 0.304731).  Saving model ...
# ------------------------------------------------------------
#   Batch    10  of    287.    Elapsed: 0:00:03.
#   Batch    20  of    287.    Elapsed: 0:00:05.
#   Batch    30  of    287.    Elapsed: 0:00:08.
#   Batch    40  of    287.    Elapsed: 0:00:11.
#   Batch    50  of    287.    Elapsed: 0:00:13.
#   Batch    60  of    287.    Elapsed: 0:00:16.
#   Batch    70  of    287.    Elapsed: 0:00:19.
#   Batch    80  of    287.    Elapsed: 0:00:22.
#   Batch    90  of    287.    Elapsed: 0:00:24.
#   Batch   100  of    287.    Elapsed: 0:00:27.
#   Batch   110  of    287.    Elapsed: 0:00:30.
#   Batch   120  of    287.    Elapsed: 0:00:32.
#   Batch   130  of    287.    Elapsed: 0:00:35.
#   Batch   140  of    287.    Elapsed: 0:00:38.
#   Batch   150  of    287.    Elapsed: 0:00:41.
#   Batch   160  of    287.    Elapsed: 0:00:44.
#   Batch   170  of    287.    Elapsed: 0:00:47.
#   Batch   180  of    287.    Elapsed: 0:00:49.
#   Batch   190  of    287.    Elapsed: 0:00:52.
#   Batch   200  of    287.    Elapsed: 0:00:54.
#   Batch   210  of    287.    Elapsed: 0:00:57.
#   Batch   220  of    287.    Elapsed: 0:01:00.
#   Batch   230  of    287.    Elapsed: 0:01:03.
#   Batch   240  of    287.    Elapsed: 0:01:05.
#   Batch   250  of    287.    Elapsed: 0:01:08.
#   Batch   260  of    287.    Elapsed: 0:01:11.
#   Batch   270  of    287.    Elapsed: 0:01:14.
#   Batch   280  of    287.    Elapsed: 0:01:17.
#   Batch    10  of     36.    Elapsed: 0:01:20.
#   Batch    20  of     36.    Elapsed: 0:01:20.
#   Batch    30  of     36.    Elapsed: 0:01:22.
# Epoch [16/30], Train Loss: 0.2905, Train Accuracy: 0.8905
# Epoch [16/30], Val Loss: 0.3174, Val Accuracy: 0.8806
# EarlyStopping counter: 1 out of 5
# ------------------------------------------------------------
#   Batch    10  of    287.    Elapsed: 0:00:03.
#   Batch    20  of    287.    Elapsed: 0:00:06.
#   Batch    30  of    287.    Elapsed: 0:00:08.
#   Batch    40  of    287.    Elapsed: 0:00:11.
#   Batch    50  of    287.    Elapsed: 0:00:14.
#   Batch    60  of    287.    Elapsed: 0:00:17.
#   Batch    70  of    287.    Elapsed: 0:00:20.
#   Batch    80  of    287.    Elapsed: 0:00:22.
#   Batch    90  of    287.    Elapsed: 0:00:25.
#   Batch   100  of    287.    Elapsed: 0:00:28.
#   Batch   110  of    287.    Elapsed: 0:00:31.
#   Batch   120  of    287.    Elapsed: 0:00:34.
#   Batch   130  of    287.    Elapsed: 0:00:36.
#   Batch   140  of    287.    Elapsed: 0:00:39.
#   Batch   150  of    287.    Elapsed: 0:00:42.
#   Batch   160  of    287.    Elapsed: 0:00:44.
#   Batch   170  of    287.    Elapsed: 0:00:47.
#   Batch   180  of    287.    Elapsed: 0:00:49.
#   Batch   190  of    287.    Elapsed: 0:00:52.
#   Batch   200  of    287.    Elapsed: 0:00:55.
#   Batch   210  of    287.    Elapsed: 0:00:58.
#   Batch   220  of    287.    Elapsed: 0:01:00.
#   Batch   230  of    287.    Elapsed: 0:01:03.
#   Batch   240  of    287.    Elapsed: 0:01:05.
#   Batch   250  of    287.    Elapsed: 0:01:08.
#   Batch   260  of    287.    Elapsed: 0:01:11.
#   Batch   270  of    287.    Elapsed: 0:01:14.
#   Batch   280  of    287.    Elapsed: 0:01:16.
#   Batch    10  of     36.    Elapsed: 0:01:19.
#   Batch    20  of     36.    Elapsed: 0:01:20.
#   Batch    30  of     36.    Elapsed: 0:01:21.
# Epoch [17/30], Train Loss: 0.2840, Train Accuracy: 0.8924
# Epoch [17/30], Val Loss: 0.3123, Val Accuracy: 0.8819
# EarlyStopping counter: 2 out of 5
# ------------------------------------------------------------
#   Batch    10  of    287.    Elapsed: 0:00:03.
#   Batch    20  of    287.    Elapsed: 0:00:05.
#   Batch    30  of    287.    Elapsed: 0:00:08.
#   Batch    40  of    287.    Elapsed: 0:00:11.
#   Batch    50  of    287.    Elapsed: 0:00:13.
#   Batch    60  of    287.    Elapsed: 0:00:16.
#   Batch    70  of    287.    Elapsed: 0:00:18.
#   Batch    80  of    287.    Elapsed: 0:00:21.
#   Batch    90  of    287.    Elapsed: 0:00:23.
#   Batch   100  of    287.    Elapsed: 0:00:26.
#   Batch   110  of    287.    Elapsed: 0:00:29.
#   Batch   120  of    287.    Elapsed: 0:00:31.
#   Batch   130  of    287.    Elapsed: 0:00:34.
#   Batch   140  of    287.    Elapsed: 0:00:37.
#   Batch   150  of    287.    Elapsed: 0:00:39.
#   Batch   160  of    287.    Elapsed: 0:00:42.
#   Batch   170  of    287.    Elapsed: 0:00:45.
#   Batch   180  of    287.    Elapsed: 0:00:47.
#   Batch   190  of    287.    Elapsed: 0:00:50.
#   Batch   200  of    287.    Elapsed: 0:00:52.
#   Batch   210  of    287.    Elapsed: 0:00:55.
#   Batch   220  of    287.    Elapsed: 0:00:58.
#   Batch   230  of    287.    Elapsed: 0:01:00.
#   Batch   240  of    287.    Elapsed: 0:01:03.
#   Batch   250  of    287.    Elapsed: 0:01:06.
#   Batch   260  of    287.    Elapsed: 0:01:08.
#   Batch   270  of    287.    Elapsed: 0:01:11.
#   Batch   280  of    287.    Elapsed: 0:01:14.
#   Batch    10  of     36.    Elapsed: 0:01:16.
#   Batch    20  of     36.    Elapsed: 0:01:18.
#   Batch    30  of     36.    Elapsed: 0:01:19.
# Epoch [18/30], Train Loss: 0.2814, Train Accuracy: 0.8953
# Epoch [18/30], Val Loss: 0.3121, Val Accuracy: 0.8878
# EarlyStopping counter: 3 out of 5
# ------------------------------------------------------------
#   Batch    10  of    287.    Elapsed: 0:00:03.
#   Batch    20  of    287.    Elapsed: 0:00:06.
#   Batch    30  of    287.    Elapsed: 0:00:08.
#   Batch    40  of    287.    Elapsed: 0:00:11.
#   Batch    50  of    287.    Elapsed: 0:00:13.
#   Batch    60  of    287.    Elapsed: 0:00:16.
#   Batch    70  of    287.    Elapsed: 0:00:19.
#   Batch    80  of    287.    Elapsed: 0:00:21.
#   Batch    90  of    287.    Elapsed: 0:00:24.
#   Batch   100  of    287.    Elapsed: 0:00:27.
#   Batch   110  of    287.    Elapsed: 0:00:29.
#   Batch   120  of    287.    Elapsed: 0:00:32.
#   Batch   130  of    287.    Elapsed: 0:00:34.
#   Batch   140  of    287.    Elapsed: 0:00:37.
#   Batch   150  of    287.    Elapsed: 0:00:40.
#   Batch   160  of    287.    Elapsed: 0:00:42.
#   Batch   170  of    287.    Elapsed: 0:00:45.
#   Batch   180  of    287.    Elapsed: 0:00:47.
#   Batch   190  of    287.    Elapsed: 0:00:50.
#   Batch   200  of    287.    Elapsed: 0:00:53.
#   Batch   210  of    287.    Elapsed: 0:00:55.
#   Batch   220  of    287.    Elapsed: 0:00:58.
#   Batch   230  of    287.    Elapsed: 0:01:01.
#   Batch   240  of    287.    Elapsed: 0:01:04.
#   Batch   250  of    287.    Elapsed: 0:01:07.
#   Batch   260  of    287.    Elapsed: 0:01:09.
#   Batch   270  of    287.    Elapsed: 0:01:12.
#   Batch   280  of    287.    Elapsed: 0:01:15.
#   Batch    10  of     36.    Elapsed: 0:01:18.
#   Batch    20  of     36.    Elapsed: 0:01:19.
#   Batch    30  of     36.    Elapsed: 0:01:20.
# Epoch [19/30], Train Loss: 0.2769, Train Accuracy: 0.8975
# Epoch [19/30], Val Loss: 0.2977, Val Accuracy: 0.8828
# Validation loss decreased (0.304731 --> 0.297736).  Saving model ...
# ------------------------------------------------------------
#   Batch    10  of    287.    Elapsed: 0:00:03.
#   Batch    20  of    287.    Elapsed: 0:00:06.
#   Batch    30  of    287.    Elapsed: 0:00:09.
#   Batch    40  of    287.    Elapsed: 0:00:12.
#   Batch    50  of    287.    Elapsed: 0:00:15.
#   Batch    60  of    287.    Elapsed: 0:00:18.
#   Batch    70  of    287.    Elapsed: 0:00:21.
#   Batch    80  of    287.    Elapsed: 0:00:24.
#   Batch    90  of    287.    Elapsed: 0:00:26.
#   Batch   100  of    287.    Elapsed: 0:00:29.
#   Batch   110  of    287.    Elapsed: 0:00:32.
#   Batch   120  of    287.    Elapsed: 0:00:34.
#   Batch   130  of    287.    Elapsed: 0:00:37.
#   Batch   140  of    287.    Elapsed: 0:00:39.
#   Batch   150  of    287.    Elapsed: 0:00:42.
#   Batch   160  of    287.    Elapsed: 0:00:45.
#   Batch   170  of    287.    Elapsed: 0:00:47.
#   Batch   180  of    287.    Elapsed: 0:00:50.
#   Batch   190  of    287.    Elapsed: 0:00:52.
#   Batch   200  of    287.    Elapsed: 0:00:55.
#   Batch   210  of    287.    Elapsed: 0:00:58.
#   Batch   220  of    287.    Elapsed: 0:01:00.
#   Batch   230  of    287.    Elapsed: 0:01:03.
#   Batch   240  of    287.    Elapsed: 0:01:06.
#   Batch   250  of    287.    Elapsed: 0:01:08.
#   Batch   260  of    287.    Elapsed: 0:01:11.
#   Batch   270  of    287.    Elapsed: 0:01:13.
#   Batch   280  of    287.    Elapsed: 0:01:16.
#   Batch    10  of     36.    Elapsed: 0:01:19.
#   Batch    20  of     36.    Elapsed: 0:01:20.
#   Batch    30  of     36.    Elapsed: 0:01:21.
# Epoch [20/30], Train Loss: 0.2734, Train Accuracy: 0.8995
# Epoch [20/30], Val Loss: 0.2975, Val Accuracy: 0.8845
# Validation loss decreased (0.297736 --> 0.297473).  Saving model ...
# ------------------------------------------------------------
#   Batch    10  of    287.    Elapsed: 0:00:03.
#   Batch    20  of    287.    Elapsed: 0:00:05.
#   Batch    30  of    287.    Elapsed: 0:00:08.
#   Batch    40  of    287.    Elapsed: 0:00:11.
#   Batch    50  of    287.    Elapsed: 0:00:13.
#   Batch    60  of    287.    Elapsed: 0:00:16.
#   Batch    70  of    287.    Elapsed: 0:00:18.
#   Batch    80  of    287.    Elapsed: 0:00:21.
#   Batch    90  of    287.    Elapsed: 0:00:23.
#   Batch   100  of    287.    Elapsed: 0:00:26.
#   Batch   110  of    287.    Elapsed: 0:00:29.
#   Batch   120  of    287.    Elapsed: 0:00:31.
#   Batch   130  of    287.    Elapsed: 0:00:34.
#   Batch   140  of    287.    Elapsed: 0:00:36.
#   Batch   150  of    287.    Elapsed: 0:00:39.
#   Batch   160  of    287.    Elapsed: 0:00:41.
#   Batch   170  of    287.    Elapsed: 0:00:44.
#   Batch   180  of    287.    Elapsed: 0:00:46.
#   Batch   190  of    287.    Elapsed: 0:00:49.
#   Batch   200  of    287.    Elapsed: 0:00:52.
#   Batch   210  of    287.    Elapsed: 0:00:54.
#   Batch   220  of    287.    Elapsed: 0:00:57.
#   Batch   230  of    287.    Elapsed: 0:00:59.
#   Batch   240  of    287.    Elapsed: 0:01:02.
#   Batch   250  of    287.    Elapsed: 0:01:04.
#   Batch   260  of    287.    Elapsed: 0:01:07.
#   Batch   270  of    287.    Elapsed: 0:01:10.
#   Batch   280  of    287.    Elapsed: 0:01:12.
#   Batch    10  of     36.    Elapsed: 0:01:15.
#   Batch    20  of     36.    Elapsed: 0:01:16.
#   Batch    30  of     36.    Elapsed: 0:01:17.
# Epoch [21/30], Train Loss: 0.2680, Train Accuracy: 0.9017
# Epoch [21/30], Val Loss: 0.2925, Val Accuracy: 0.8898
# Validation loss decreased (0.297473 --> 0.292500).  Saving model ...
# ------------------------------------------------------------
#   Batch    10  of    287.    Elapsed: 0:00:03.
#   Batch    20  of    287.    Elapsed: 0:00:06.
#   Batch    30  of    287.    Elapsed: 0:00:08.
#   Batch    40  of    287.    Elapsed: 0:00:11.
#   Batch    50  of    287.    Elapsed: 0:00:14.
#   Batch    60  of    287.    Elapsed: 0:00:16.
#   Batch    70  of    287.    Elapsed: 0:00:19.
#   Batch    80  of    287.    Elapsed: 0:00:22.
#   Batch    90  of    287.    Elapsed: 0:00:24.
#   Batch   100  of    287.    Elapsed: 0:00:27.
#   Batch   110  of    287.    Elapsed: 0:00:30.
#   Batch   120  of    287.    Elapsed: 0:00:32.
#   Batch   130  of    287.    Elapsed: 0:00:35.
#   Batch   140  of    287.    Elapsed: 0:00:38.
#   Batch   150  of    287.    Elapsed: 0:00:40.
#   Batch   160  of    287.    Elapsed: 0:00:43.
#   Batch   170  of    287.    Elapsed: 0:00:45.
#   Batch   180  of    287.    Elapsed: 0:00:48.
#   Batch   190  of    287.    Elapsed: 0:00:50.
#   Batch   200  of    287.    Elapsed: 0:00:53.
#   Batch   210  of    287.    Elapsed: 0:00:55.
#   Batch   220  of    287.    Elapsed: 0:00:58.
#   Batch   230  of    287.    Elapsed: 0:01:01.
#   Batch   240  of    287.    Elapsed: 0:01:03.
#   Batch   250  of    287.    Elapsed: 0:01:06.
#   Batch   260  of    287.    Elapsed: 0:01:09.
#   Batch   270  of    287.    Elapsed: 0:01:11.
#   Batch   280  of    287.    Elapsed: 0:01:14.
#   Batch    10  of     36.    Elapsed: 0:01:16.
#   Batch    20  of     36.    Elapsed: 0:01:17.
#   Batch    30  of     36.    Elapsed: 0:01:18.
# Epoch [22/30], Train Loss: 0.2585, Train Accuracy: 0.9052
# Epoch [22/30], Val Loss: 0.3120, Val Accuracy: 0.8908
# EarlyStopping counter: 1 out of 5
# ------------------------------------------------------------
#   Batch    10  of    287.    Elapsed: 0:00:03.
#   Batch    20  of    287.    Elapsed: 0:00:06.
#   Batch    30  of    287.    Elapsed: 0:00:09.
#   Batch    40  of    287.    Elapsed: 0:00:12.
#   Batch    50  of    287.    Elapsed: 0:00:14.
#   Batch    60  of    287.    Elapsed: 0:00:17.
#   Batch    70  of    287.    Elapsed: 0:00:20.
#   Batch    80  of    287.    Elapsed: 0:00:22.
#   Batch    90  of    287.    Elapsed: 0:00:25.
#   Batch   100  of    287.    Elapsed: 0:00:27.
#   Batch   110  of    287.    Elapsed: 0:00:30.
#   Batch   120  of    287.    Elapsed: 0:00:33.
#   Batch   130  of    287.    Elapsed: 0:00:35.
#   Batch   140  of    287.    Elapsed: 0:00:38.
#   Batch   150  of    287.    Elapsed: 0:00:40.
#   Batch   160  of    287.    Elapsed: 0:00:43.
#   Batch   170  of    287.    Elapsed: 0:00:46.
#   Batch   180  of    287.    Elapsed: 0:00:49.
#   Batch   190  of    287.    Elapsed: 0:00:51.
#   Batch   200  of    287.    Elapsed: 0:00:54.
#   Batch   210  of    287.    Elapsed: 0:00:57.
#   Batch   220  of    287.    Elapsed: 0:00:59.
#   Batch   230  of    287.    Elapsed: 0:01:02.
#   Batch   240  of    287.    Elapsed: 0:01:04.
#   Batch   250  of    287.    Elapsed: 0:01:07.
#   Batch   260  of    287.    Elapsed: 0:01:10.
#   Batch   270  of    287.    Elapsed: 0:01:12.
#   Batch   280  of    287.    Elapsed: 0:01:15.
#   Batch    10  of     36.    Elapsed: 0:01:17.
#   Batch    20  of     36.    Elapsed: 0:01:18.
#   Batch    30  of     36.    Elapsed: 0:01:19.
# Epoch [23/30], Train Loss: 0.2517, Train Accuracy: 0.9079
# Epoch [23/30], Val Loss: 0.2943, Val Accuracy: 0.8906
# EarlyStopping counter: 2 out of 5
# ------------------------------------------------------------
#   Batch    10  of    287.    Elapsed: 0:00:03.
#   Batch    20  of    287.    Elapsed: 0:00:05.
#   Batch    30  of    287.    Elapsed: 0:00:08.
#   Batch    40  of    287.    Elapsed: 0:00:11.
#   Batch    50  of    287.    Elapsed: 0:00:13.
#   Batch    60  of    287.    Elapsed: 0:00:16.
#   Batch    70  of    287.    Elapsed: 0:00:18.
#   Batch    80  of    287.    Elapsed: 0:00:21.
#   Batch    90  of    287.    Elapsed: 0:00:24.
#   Batch   100  of    287.    Elapsed: 0:00:26.
#   Batch   110  of    287.    Elapsed: 0:00:29.
#   Batch   120  of    287.    Elapsed: 0:00:32.
#   Batch   130  of    287.    Elapsed: 0:00:34.
#   Batch   140  of    287.    Elapsed: 0:00:37.
#   Batch   150  of    287.    Elapsed: 0:00:40.
#   Batch   160  of    287.    Elapsed: 0:00:43.
#   Batch   170  of    287.    Elapsed: 0:00:46.
#   Batch   180  of    287.    Elapsed: 0:00:49.
#   Batch   190  of    287.    Elapsed: 0:00:51.
#   Batch   200  of    287.    Elapsed: 0:00:54.
#   Batch   210  of    287.    Elapsed: 0:00:56.
#   Batch   220  of    287.    Elapsed: 0:00:59.
#   Batch   230  of    287.    Elapsed: 0:01:02.
#   Batch   240  of    287.    Elapsed: 0:01:05.
#   Batch   250  of    287.    Elapsed: 0:01:07.
#   Batch   260  of    287.    Elapsed: 0:01:10.
#   Batch   270  of    287.    Elapsed: 0:01:13.
#   Batch   280  of    287.    Elapsed: 0:01:15.
#   Batch    10  of     36.    Elapsed: 0:01:18.
#   Batch    20  of     36.    Elapsed: 0:01:19.
#   Batch    30  of     36.    Elapsed: 0:01:20.
# Epoch [24/30], Train Loss: 0.2481, Train Accuracy: 0.9095
# Epoch [24/30], Val Loss: 0.3255, Val Accuracy: 0.8815
# EarlyStopping counter: 3 out of 5
# ------------------------------------------------------------
#   Batch    10  of    287.    Elapsed: 0:00:03.
#   Batch    20  of    287.    Elapsed: 0:00:06.
#   Batch    30  of    287.    Elapsed: 0:00:09.
#   Batch    40  of    287.    Elapsed: 0:00:12.
#   Batch    50  of    287.    Elapsed: 0:00:14.
#   Batch    60  of    287.    Elapsed: 0:00:17.
#   Batch    70  of    287.    Elapsed: 0:00:19.
#   Batch    80  of    287.    Elapsed: 0:00:22.
#   Batch    90  of    287.    Elapsed: 0:00:25.
#   Batch   100  of    287.    Elapsed: 0:00:28.
#   Batch   110  of    287.    Elapsed: 0:00:30.
#   Batch   120  of    287.    Elapsed: 0:00:33.
#   Batch   130  of    287.    Elapsed: 0:00:35.
#   Batch   140  of    287.    Elapsed: 0:00:38.
#   Batch   150  of    287.    Elapsed: 0:00:41.
#   Batch   160  of    287.    Elapsed: 0:00:44.
#   Batch   170  of    287.    Elapsed: 0:00:46.
#   Batch   180  of    287.    Elapsed: 0:00:49.
#   Batch   190  of    287.    Elapsed: 0:00:51.
#   Batch   200  of    287.    Elapsed: 0:00:54.
#   Batch   210  of    287.    Elapsed: 0:00:57.
#   Batch   220  of    287.    Elapsed: 0:00:59.
#   Batch   230  of    287.    Elapsed: 0:01:02.
#   Batch   240  of    287.    Elapsed: 0:01:05.
#   Batch   250  of    287.    Elapsed: 0:01:07.
#   Batch   260  of    287.    Elapsed: 0:01:10.
#   Batch   270  of    287.    Elapsed: 0:01:12.
#   Batch   280  of    287.    Elapsed: 0:01:15.
#   Batch    10  of     36.    Elapsed: 0:01:18.
#   Batch    20  of     36.    Elapsed: 0:01:19.
#   Batch    30  of     36.    Elapsed: 0:01:20.
# Epoch [25/30], Train Loss: 0.2400, Train Accuracy: 0.9131
# Epoch [25/30], Val Loss: 0.3210, Val Accuracy: 0.8854
# EarlyStopping counter: 4 out of 5
# ------------------------------------------------------------
#   Batch    10  of    287.    Elapsed: 0:00:03.
#   Batch    20  of    287.    Elapsed: 0:00:05.
#   Batch    30  of    287.    Elapsed: 0:00:08.
#   Batch    40  of    287.    Elapsed: 0:00:10.
#   Batch    50  of    287.    Elapsed: 0:00:13.
#   Batch    60  of    287.    Elapsed: 0:00:16.
#   Batch    70  of    287.    Elapsed: 0:00:18.
#   Batch    80  of    287.    Elapsed: 0:00:21.
#   Batch    90  of    287.    Elapsed: 0:00:23.
#   Batch   100  of    287.    Elapsed: 0:00:26.
#   Batch   110  of    287.    Elapsed: 0:00:29.
#   Batch   120  of    287.    Elapsed: 0:00:31.
#   Batch   130  of    287.    Elapsed: 0:00:34.
#   Batch   140  of    287.    Elapsed: 0:00:36.
#   Batch   150  of    287.    Elapsed: 0:00:39.
#   Batch   160  of    287.    Elapsed: 0:00:42.
#   Batch   170  of    287.    Elapsed: 0:00:44.
#   Batch   180  of    287.    Elapsed: 0:00:47.
#   Batch   190  of    287.    Elapsed: 0:00:49.
#   Batch   200  of    287.    Elapsed: 0:00:52.
#   Batch   210  of    287.    Elapsed: 0:00:55.
#   Batch   220  of    287.    Elapsed: 0:00:57.
#   Batch   230  of    287.    Elapsed: 0:01:00.
#   Batch   240  of    287.    Elapsed: 0:01:03.
#   Batch   250  of    287.    Elapsed: 0:01:05.
#   Batch   260  of    287.    Elapsed: 0:01:08.
#   Batch   270  of    287.    Elapsed: 0:01:10.
#   Batch   280  of    287.    Elapsed: 0:01:13.
#   Batch    10  of     36.    Elapsed: 0:01:16.
#   Batch    20  of     36.    Elapsed: 0:01:17.
#   Batch    30  of     36.    Elapsed: 0:01:18.
# Epoch [26/30], Train Loss: 0.2338, Train Accuracy: 0.9186
# Epoch [26/30], Val Loss: 0.3442, Val Accuracy: 0.8700
# EarlyStopping counter: 5 out of 5
# Early stopping
# ------------------------------------------------------------

# %%
torch.save(model.state_dict(), "eff_b3_normal_preproc.pt")

# %% [markdown]
# ### Testing on split

# %%
model = model.train(False)

# %%
torch.cuda.empty_cache()

# %%
test_loss = 0
test_acc  = 0
for batch_idx, (data, targets) in enumerate((test_dataloader)):
    data = data.to(device)
    targets = targets.to(device)
    with torch.no_grad():
        scores = model(data)
        scores = torch.sigmoid(scores)

    loss = criterion(scores, targets.float())
    test_loss+= loss.item()
    preds = predictions(scores).to(device)
    test_acc+= (torch.sum(preds == targets)/(BATCH_SIZE*8))

avg_test_loss = test_loss/len(test_dataloader)
avg_test_acc  = test_acc /len(test_dataloader)

# %%
avg_test_loss, avg_test_acc.item()
# Out:
# (0.34563953760597443, 0.8700087070465088)

# %% [markdown]
# ## Testing on preheld testing set
#
# |Metric  |Value|
# |:------:|-----|
# |Accuracy|0.891|
# |Loss    |0.330|

# %%
model = torchvision.models.efficientnet_b3(parameters = {'weights': torchvision.models.EfficientNet_B3_Weights.DEFAULT}).to(device)
num_ftrs = model.classifier[1].in_features
NUM_CLASSES = 8
model.classifier[1] = torch.nn.Linear(in_features=num_ftrs, out_features=NUM_CLASSES, bias=True)
model.classifier[0] = torch.nn.Dropout(p=0.5, inplace=True)
model = model.to(device)

model.load_state_dict(torch.load('eff_b3_normal_preproc.pt'))
# Print the model summary
# summary(model, (3, 299, 299))
# Out:
# <All keys matched successfully>

# %%
test_csv = pd.read_csv(TEST_CSV)
test_csv = test_csv.drop(columns = ['ID', 'Patient Age', 'Patient Sex', 'eye', 'NOT DECISIVE'])
test_csv.head()
# Out:
#             Image  N  D  G  C  A  H  M  O
# 0   1590_left.jpg  1  0  0  0  0  0  0  0
# 1   3137_left.jpg  1  0  0  0  0  0  0  0
# 2  4182_right.jpg  1  0  0  0  0  0  0  0
# 3   3333_left.jpg  1  0  0  0  0  0  0  0
# 4  4459_right.jpg  0  1  0  0  0  0  0  0

# %%
X_test = test_csv['Image'].to_numpy()
Y_test = test_csv.drop(['Image'], axis = 1).to_numpy()

X_test.shape, Y_test.shape
# Out:
# ((638,), (638, 8))

# %%
class ODIRDataset(Dataset) :
    
    def __init__(self, X, Y, IMG_FOLDER, transform = None) :
        
        '''
        id : list of samples ids as string
        '''

        self.images = X
        self.labels = Y
        self.image_dir = IMG_FOLDER
        self.transform = transform
        
    def __len__(self):
        return len(self.images)
        
    def __getitem__(self, idx):
        
        img_path = os.path.join(self.image_dir, self.images[idx])
        
        image = Image.open(img_path).convert("RGB")

        labels = torch.Tensor(self.labels[idx]).long()

        if(self.transform != None) :
          image = self.transform(image)

        return image, labels

# %%
BATCH_SIZE = 16

# %%
def binary_cross_entropy(y_true, y_pred):
    epsilon = 1e-15
    y_pred = torch.clamp(y_pred, min = epsilon, max = 1-epsilon)
    loss = -(y_true * torch.log(y_pred) + (1 - y_true) * torch.log(1 - y_pred))
    mean_loss = torch.mean(loss)
    return mean_loss

def criterion(y_true_batch, y_pred_batch) :
    B = y_true_batch.shape[0]
    loss = 0 
    for i in range(B) :
      loss += binary_cross_entropy(y_true_batch[i], y_pred_batch[i])
    return loss/B 

def predictions(scores) :
    
    B = scores.shape[0]
    predictions = torch.empty(B, NUM_CLASSES)
    
    for i in range(B) :
      pred = torch.empty(NUM_CLASSES,)
      for j in range(NUM_CLASSES) : 
        if(scores[i][j] > 0.5) :
          pred[j] = 1
        else :
          pred[j] = 0
      predictions[i] = pred

    return predictions

# %%
weight_class = torch.tensor([1,1.2,1.5,1.5,1.5,1.5, 1.5, 1.2]).to(device)
criterion = torch.nn.BCELoss(weight_class)

# %%
test_dataset = ODIRDataset(X_test, Y_test, IMAGE_FOLDER, transform = transforms.Compose([transforms.ToTensor()]))
test_dataloader_preheld = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
model = model.train(False)

# %%
torch.cuda.empty_cache()

# %%
test_loss = 0
test_acc  = 0
PREC = torchmetrics.classification.MultilabelPrecision(8, average = 'micro')#, validate_args = False)
ACC = torchmetrics.classification.MultilabelAccuracy(8, average = 'micro')#, validate_args = False)
REC = torchmetrics.classification.MultilabelRecall(8, average = 'micro')#, validate_args = False)
F1_SCORE = torchmetrics.classification.MultilabelF1Score(8, average = 'micro')#, validate_args = False)
F_BETA_SCORE = torchmetrics.classification.MultilabelFBetaScore(beta = 0.8, num_classes = 8, num_labels = 8, average = 'micro')#, validate_args = False)
KAPPA = torchmetrics.classification.MulticlassCohenKappa(8)#, validate_args = False)
AUC = torchmetrics.classification.MultilabelAUROC(8, average = 'micro')#, validate_args = False)

for batch_idx, (data, targets) in enumerate((test_dataloader_preheld)):
    data = data.to(device)
    targets = targets.to(device)
    with torch.no_grad():
        scores = model(data)
        scores = torch.sigmoid(scores)
    loss = criterion(scores, targets.float())
    test_loss+= loss.item()
    predicted = predictions(scores).to(device)
    test_acc+= (torch.sum(predicted == targets)/(BATCH_SIZE*8))

    predicted = predicted.to('cpu')
    targets = targets.to('cpu')
    PREC(predicted, targets)
    ACC(predicted, targets)
    REC(predicted, targets)
    F1_SCORE(predicted, targets)
    F_BETA_SCORE(predicted, targets)
    KAPPA(predicted, targets)
    AUC(predicted, targets)


add_prec = PREC.compute()
add_acc = ACC.compute()
add_rec = REC.compute()
add_f1 = F1_SCORE.compute()
add_fbeta = F_BETA_SCORE.compute()
add_kappa = KAPPA.compute()
add_auc = AUC.compute()

avg_test_loss = test_loss/len(test_dataloader_preheld)
avg_test_acc  = test_acc /len(test_dataloader_preheld)

print("Acc: {:3f}\nPrec: {:3f}\nRecall: {:.3f}\nF1-score: {:.3f}\nF-Beta-score: {:.3f}\nKappa: {:.3f}\nAUC: {:.3f}".format(add_acc, add_prec,add_rec, add_f1, add_fbeta, add_kappa, add_auc))
torch.cuda.empty_cache()
# Out:
# Acc: 0.875588
# Prec: 0.502773
# Recall: 0.426
# F1-score: 0.461
# F-Beta-score: 0.470
# Kappa: 0.392
# AUC: 0.683

# %%
avg_test_loss, avg_test_acc.item()
# Out:
# (0.3445025641471148, 0.872851550579071)
