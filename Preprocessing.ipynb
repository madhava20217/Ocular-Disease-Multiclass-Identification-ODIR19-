# %% [markdown]
# # Preprocessing

# %%
#requirements:
# opendatasets, pandas, openpyxl

import opendatasets as od
import pandas as pd
import zipfile
import os
import re
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

DOWNLOAD_DIR = 'Datasets'
DATASET_LOC = DOWNLOAD_DIR+"/ocular-disease-recognition-odir5k/ODIR-5K/ODIR-5k/"

# %% [markdown]
# ## Downloading the Dataset

# %%
od.download_kaggle_dataset('https://www.kaggle.com/datasets/andrewmvd/ocular-disease-recognition-odir5k', data_dir = DOWNLOAD_DIR, force = False)
# Out:
# Skipping, found downloaded files in "Datasets\ocular-disease-recognition-odir5k" (use force=True to force download)

# %% [markdown]
# ## Importing the dataset
#
# The dataset has 5000 fundus images

# %%
df = pd.read_excel(DATASET_LOC + 'data.xlsx', index_col = 'ID')
df.head()
# Out:
#     Patient Age Patient Sex Left-Fundus Right-Fundus  \
# ID
# 0            69      Female  0_left.jpg  0_right.jpg
# 1            57        Male  1_left.jpg  1_right.jpg
# 2            42        Male  2_left.jpg  2_right.jpg
# 3            66        Male  3_left.jpg  3_right.jpg
# 4            53        Male  4_left.jpg  4_right.jpg
#
#                              Left-Diagnostic Keywords  \
# ID
# 0                                            cataract
# 1                                       normal fundus
# 2   laser spot，moderate non proliferative retinopathy
# 3                                       normal fundus
# 4                         macular epiretinal membrane
#
#                  Right-Diagnostic Keywords  N  D  G  C  A  H  M  O
# ID
# 0                            normal fundus  0  0  0  1  0  0  0  0
# 1                            normal fundus  1  0  0  0  0  0  0  0
# 2   moderate non proliferative retinopathy  0  1  0  0  0  0  0  1
# 3          branch retinal artery occlusion  0  0  0  0  0  0  0  1
# 4        mild nonproliferative retinopathy  0  1  0  0  0  0  0  1

# %%
df[['N', 'D', 'G', 'C', 'A', 'H', 'M', 'O']].sum()
# Out:
# N    1140
# D    1128
# G     215
# C     212
# A     164
# H     103
# M     174
# O     979
# dtype: int64

# %%
df[df.D == 1]
# Out:
#       Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# ID
# 2              42        Male     2_left.jpg     2_right.jpg
# 4              53        Male     4_left.jpg     4_right.jpg
# 5              50      Female     5_left.jpg     5_right.jpg
# 6              60        Male     6_left.jpg     6_right.jpg
# 7              60      Female     7_left.jpg     7_right.jpg
# ...           ...         ...            ...             ...
# 4683           58        Male  4683_left.jpg  4683_right.jpg
# 4686           63        Male  4686_left.jpg  4686_right.jpg
# 4688           42        Male  4688_left.jpg  4688_right.jpg
# 4689           54        Male  4689_left.jpg  4689_right.jpg
# 4690           57        Male  4690_left.jpg  4690_right.jpg
#
#                                Left-Diagnostic Keywords  \
# ID
# 2     laser spot，moderate non proliferative retinopathy
# 4                           macular epiretinal membrane
# 5                moderate non proliferative retinopathy
# 6                           macular epiretinal membrane
# 7                                                drusen
# ...                                                 ...
# 4683                                      normal fundus
# 4686                severe nonproliferative retinopathy
# 4688             moderate non proliferative retinopathy
# 4689                  mild nonproliferative retinopathy
# 4690                  mild nonproliferative retinopathy
#
#                               Right-Diagnostic Keywords  N  D  G  C  A  H  M  \
# ID
# 2                moderate non proliferative retinopathy  0  1  0  0  0  0  0
# 4                     mild nonproliferative retinopathy  0  1  0  0  0  0  0
# 5                moderate non proliferative retinopathy  0  1  0  0  0  0  0
# 6     moderate non proliferative retinopathy，epireti...  0  1  0  0  0  0  0
# 7                     mild nonproliferative retinopathy  0  1  0  0  0  0  0
# ...                                                 ... .. .. .. .. .. .. ..
# 4683                  mild nonproliferative retinopathy  0  1  0  0  0  0  0
# 4686                 proliferative diabetic retinopathy  0  1  0  0  0  0  0
# 4688             moderate non proliferative retinopathy  0  1  0  0  0  0  0
# 4689                                      normal fundus  0  1  0  0  0  0  0
# 4690                  mild nonproliferative retinopathy  0  1  0  0  0  0  0
#
#       O
# ID
# 2     1
# 4     1
# 5     0
# 6     1
# 7     1
# ...  ..
# 4683  0
# 4686  0
# 4688  0
# 4689  0
# 4690  0
#
# [1128 rows x 14 columns]

# %%
#extracting left and right indices for diabetic retinopathy
left_right_ids = df[df.D == 1][['Left-Diagnostic Keywords', 'Right-Diagnostic Keywords']]
left_right_ids['Left-Diagnostic Keywords'] = left_right_ids['Left-Diagnostic Keywords'].str.extract(r".*(retinopathy).*", re.IGNORECASE)
left_right_ids['Right-Diagnostic Keywords'] = left_right_ids['Right-Diagnostic Keywords'].str.extract(r".*(retinopathy).*", re.IGNORECASE)

left = left_right_ids['Left-Diagnostic Keywords']
right = left_right_ids['Right-Diagnostic Keywords']

left_idx = left[~left.isna()].index
right_idx = right[~right.isna()].index

# %%
left_diabetes = df.loc[left_idx]
right_diabetes = df.loc[right_idx]

# %%
(left_diabetes['D'] == 1).all(), (right_diabetes['D'] == 1).all()
# Out:
# (True, True)

# %%
left_diabetes = left_diabetes[['Patient Age', 'Patient Sex', 'Left-Fundus', 'Left-Diagnostic Keywords']]
left_diabetes['Eye'] = 'left'
left_diabetes.rename(columns = {"Left-Fundus": "Image", "Left-Diagnostic Keywords": "Diagnostic Keywords"}, inplace = True)
left_diabetes.reset_index(inplace = True, drop = False)

right_diabetes = right_diabetes[['Patient Age', 'Patient Sex', 'Right-Fundus', 'Right-Diagnostic Keywords']]
right_diabetes['Eye'] = 'right'
right_diabetes.rename(columns = {"Right-Fundus": "Image", "Right-Diagnostic Keywords": "Diagnostic Keywords"}, inplace = True)
right_diabetes.reset_index(inplace = True, drop = False)

# %%
diabetes = pd.concat([left_diabetes, right_diabetes]).reset_index(drop = True)
diabetes.to_csv(DATASET_LOC + "diabetic_images.csv", index = False)

diabetes
# Out:
#         ID  Patient Age Patient Sex           Image  \
# 0        2           42        Male      2_left.jpg
# 1        5           50      Female      5_left.jpg
# 2       11           60      Female     11_left.jpg
# 3       19           45        Male     19_left.jpg
# 4       22           55      Female     22_left.jpg
# ...    ...          ...         ...             ...
# 1815  4682           45        Male  4682_right.jpg
# 1816  4683           58        Male  4683_right.jpg
# 1817  4686           63        Male  4686_right.jpg
# 1818  4688           42        Male  4688_right.jpg
# 1819  4690           57        Male  4690_right.jpg
#
#                                     Diagnostic Keywords    Eye
# 0     laser spot，moderate non proliferative retinopathy   left
# 1                moderate non proliferative retinopathy   left
# 2     moderate non proliferative retinopathy，hyperte...   left
# 3                     mild nonproliferative retinopathy   left
# 4     moderate non proliferative retinopathy，laser spot   left
# ...                                                 ...    ...
# 1815             moderate non proliferative retinopathy  right
# 1816                  mild nonproliferative retinopathy  right
# 1817                 proliferative diabetic retinopathy  right
# 1818             moderate non proliferative retinopathy  right
# 1819                  mild nonproliferative retinopathy  right
#
# [1820 rows x 6 columns]

# %% [markdown]
# ## Normal eyes

# %%
normal
# Out:
#       Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# ID
# 1              57        Male     1_left.jpg     1_right.jpg
# 8              59        Male     8_left.jpg     8_right.jpg
# 84             51      Female    84_left.jpg    84_right.jpg
# 191            51      Female   191_left.jpg   191_right.jpg
# 394            63        Male   394_left.jpg   394_right.jpg
# ...           ...         ...            ...             ...
# 3485           70        Male  3485_left.jpg  3485_right.jpg
# 4149           55        Male  4149_left.jpg  4149_right.jpg
# 4290           51        Male  4290_left.jpg  4290_right.jpg
# 4571           51        Male  4571_left.jpg  4571_right.jpg
# 4637           45        Male  4637_left.jpg  4637_right.jpg
#
#      Left-Diagnostic Keywords Right-Diagnostic Keywords  N  D  G  C  A  H  M  \
# ID
# 1               normal fundus             normal fundus  1  0  0  0  0  0  0
# 8               normal fundus             normal fundus  1  0  0  0  0  0  0
# 84              normal fundus             normal fundus  1  0  0  0  0  0  0
# 191             normal fundus             normal fundus  1  0  0  0  0  0  0
# 394             normal fundus             normal fundus  1  0  0  0  0  0  0
# ...                       ...                       ... .. .. .. .. .. .. ..
# 3485            normal fundus             normal fundus  1  0  0  0  0  0  0
# 4149        low image quality         low image quality  1  0  0  0  0  0  0
# 4290        low image quality             normal fundus  1  0  0  0  0  0  0
# 4571            normal fundus             normal fundus  1  0  0  0  0  0  0
# 4637            normal fundus             normal fundus  1  0  0  0  0  0  0
#
#       O
# ID
# 1     0
# 8     0
# 84    0
# 191   0
# 394   0
# ...  ..
# 3485  0
# 4149  0
# 4290  0
# 4571  0
# 4637  0
#
# [1140 rows x 14 columns]

# %%
normal = df[df['N'] == 1]
left_normal = normal[['Patient Age','Patient Sex', 
                      'Left-Fundus', 
                      'Left-Diagnostic Keywords']].reset_index().rename(columns = {"Left-Fundus":"Image",
                                                                        "Left-Diagnostic Keywords" : "Diagnostic Keywords"})
left_normal['Eye'] = 'left'

right_normal = normal[['Patient Age','Patient Sex', 
                      'Right-Fundus', 
                      'Right-Diagnostic Keywords']].reset_index().rename(columns = {"Right-Fundus":"Image",
                                                                        "Right-Diagnostic Keywords" : "Diagnostic Keywords"})
right_normal['Eye'] = 'right'

normal = pd.concat([left_normal, right_normal]).reset_index(drop = True)
normal
# Out:
#         ID  Patient Age Patient Sex           Image Diagnostic Keywords    Eye
# 0        1           57        Male      1_left.jpg       normal fundus   left
# 1        8           59        Male      8_left.jpg       normal fundus   left
# 2       84           51      Female     84_left.jpg       normal fundus   left
# 3      191           51      Female    191_left.jpg       normal fundus   left
# 4      394           63        Male    394_left.jpg       normal fundus   left
# ...    ...          ...         ...             ...                 ...    ...
# 2275  3485           70        Male  3485_right.jpg       normal fundus  right
# 2276  4149           55        Male  4149_right.jpg   low image quality  right
# 2277  4290           51        Male  4290_right.jpg       normal fundus  right
# 2278  4571           51        Male  4571_right.jpg       normal fundus  right
# 2279  4637           45        Male  4637_right.jpg       normal fundus  right
#
# [2280 rows x 6 columns]

# %%
normal['Diagnostic Keywords'].value_counts()
# Out:
# normal fundus                    2056
# lens dust，normal fundus           174
# normal fundus，lens dust            43
# low image quality                   3
# normal fundus，normal fundus         2
# lens dust，lens dust，lens dust       1
# lens dust，lens dust                 1
# Name: Diagnostic Keywords, dtype: int64

# %%
normal.to_csv(DATASET_LOC + "normal_images.csv", index = False)
